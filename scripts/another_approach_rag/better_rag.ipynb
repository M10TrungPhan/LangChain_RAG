# %% [markdown]
# ## Retrieval

# %% [markdown]
# First we have to load the corpus.

# %%
# import os
# os.environ['CUDA_VISIBLE_DEVICES'] = '1'

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pandas as pd
def cosine(u, v):
    return np.dot(u, v) / (np.linalg.norm(u) * np.linalg.norm(v))

# %%
from datasets import load_dataset
chunk_size = 150
chunk_overlap = 50
meta_corpus = load_dataset(
    "json",
    data_files=f"data/corpus_chunks_{chunk_size}_{chunk_overlap}.jsonl",
    split="train"
).to_list()

# %%
import copy
import unicodedata as ud
import re
from tqdm import tqdm
from rank_bm25 import BM25Okapi
from tqdm.notebook import tqdm
import string

def split_text(text):
    text = text.translate(str.maketrans('', '', string.punctuation))
    words = text.lower().split()
    words = [word for word in words if len(word.strip()) > 0]
    return words

## initiate BM25 retriever
tokenized_corpus = [split_text(doc["passage"]) for doc in tqdm(meta_corpus)]
bm25 = BM25Okapi(tokenized_corpus)

# %%
from sentence_transformers import SentenceTransformer
import pandas as pd
import pickle
from pyvi.ViTokenizer import tokenize
import numpy as np
from tqdm.notebook import tqdm 

## initiate semantic rertiever
with open(f'data/corpus_embedding_w150_{chunk_size}_{chunk_overlap}.pkl', 'rb') as f:
    corpus_embs = pickle.load(f)

embedder = SentenceTransformer('VoVanPhuc/sup-SimCSE-VietNamese-phobert-base')

# %%
print(len(meta_corpus))
print(len(corpus_embs))

# %% [markdown]
# To improve from simple single BM25 retriever, we now incorporate a sentence transformer model to do the semantic search. \
# We will use `bkai-foundation-models/vietnamese-bi-encoder` model which supports Vietnamese pretty well.

# %%
from copy import deepcopy
def retrieve(question, topk=5, score_evaluate ='combined_score', threshold_score= 0):
    """
    Get most relevant chunks to the question using combination of BM25 and semantic scores.
    """
    ## initialize query for each retriever (BM25 and semantic)
    tokenized_query = split_text(question)
    segmented_question = tokenize(question)
    question_emb_output = embedder.encode([segmented_question])
    question_emb = question_emb_output/ np.linalg.norm(question_emb_output, axis=1)[:, np.newaxis]

    ## get BM25 and semantic scores
    bm25_scores = bm25.get_scores(tokenized_query)
    semantic_scores = question_emb @ corpus_embs.T
    semantic_scores = semantic_scores[0]

    ## update chunks' scores. 
    max_bm25_score = max(bm25_scores)
    min_bm25_score = min(bm25_scores)
    def normalize(x):
        return (x - min_bm25_score + 0.1) / \
        (max_bm25_score - min_bm25_score + 0.1)
        
    corpus_size = len(meta_corpus)
    for i in range(corpus_size):
        meta_corpus[i]["bm25_score"] = bm25_scores[i]
        meta_corpus[i]["bm25_normed_score"] = normalize(bm25_scores[i])
        meta_corpus[i]["semantic_score"] = semantic_scores[i]
        
        meta_corpus[i]['cosine_score'] = cosine(question_emb_output[0],corpus_embs[i])

    ## compute combined score (BM25 + semantic)
    for passage in meta_corpus:
        passage["combined_score"] = passage["bm25_normed_score"] * 0.4 + \
                                    passage["semantic_score"] * 0.6
        
    ## sort passages by the combined score

    sorted_passages = sorted(meta_corpus, key=lambda x: x[score_evaluate], reverse=True)
    sorted_passages = [each for each in sorted_passages if each[score_evaluate]>threshold_score]
    return sorted_passages[:topk]

# %%
retrieve("Mía có nguồn gốc ở đâu", topk=20, score_evaluate='combined_score')

# %%
df_evalutate =  pd.read_excel('evaluat_dataset_2.xlsx' ).drop(['Unnamed: 0'], axis=1)[['question', 'answer', 'source_doc']]

# %%
df_evalutate['cosine_doc'] = None
df_evalutate['combined_doc'] = None

df_evalutate['cosine_score_results'] = None
df_evalutate['combined_score_results'] = None
topk = 3
thresh_cosine = 0
thresh_combined = 0.5
for index_evaluate in tqdm(range(len(df_evalutate))):
    test_doc = df_evalutate.iloc[index_evaluate]
    question = test_doc['question']

    # result_retrieve_cosine = retrieve(question, topk=topk, score_evaluate='cosine_score', threshold_score = thresh_cosine)
    # consine_context = ""
    # cosine_title = []
    # for index in range(len(result_retrieve_cosine)):
    #     doc_retrieved = result_retrieve_cosine[index]
    #     context_doc = f"Context [{index}]: {doc_retrieved['passage']}\nCosine_score: {doc_retrieved['cosine_score']}   Combined_score: {doc_retrieved['combined_score']}\n"
    #     consine_context += context_doc
    #     cosine_title.append(doc_retrieved['title'])

    result_retrieve_combined = retrieve(question, topk=topk, score_evaluate='combined_score', threshold_score = thresh_combined)
    combined_context = ''
    combine_title = []
    for index in range(len(result_retrieve_combined)):
        doc_retrieved = result_retrieve_combined[index]
        context_doc = f"Context [{index}]: {doc_retrieved['passage']}\nCosine_score: {doc_retrieved['cosine_score']}   Combined_score: {doc_retrieved['combined_score']}\n"
        combined_context += context_doc
        combine_title.append(doc_retrieved['title'])
    
    # df_evalutate.at[index_evaluate, 'cosine_doc'] = cosine_title
    df_evalutate.at[index_evaluate, 'combined_doc'] = combine_title


    # df_evalutate.at[index_evaluate, 'cosine_score_results'] = consine_context
    df_evalutate.at[index_evaluate, 'combined_score_results'] = combined_context

df_evalutate[['question', 'answer', 'source_doc',  'combined_doc',  'combined_score_results']].to_excel(f'{chunk_size}_{chunk_overlap}_result_evaluate_top{topk}_threshold_{thresh_combined}.xlsx')

# df_evalutate[['question', 'answer', 'source_doc', 'cosine_doc', 'combined_doc', 'cosine_score_results', 'combined_score_results']].to_excel(f'{chunk_size}_{chunk_overlap}_result_evaluate_top{topk}.xlsx')

# %%
df_evalutate.head(2)

# %% [markdown]
# ## Smoothing contexts

# %% [markdown]
# Using combination of BM25 and semantic score may still not yield the best result (because of the reasons you will see at the end of this section) \
# We can do better by applying several techniques to form suitable contexts to feed to the LLM. \
# The following blocs will implement some utility functions with such techniques.

# %%
from copy import deepcopy
from underthesea import sent_tokenize

# GET DOCUMENT IS consecutive
def extract_consecutive_subarray(numbers):
    subarrays = []
    current_subarray = []
    for num in numbers:
        if not current_subarray or num == current_subarray[-1] + 1:
            current_subarray.append(num)
        else:
            subarrays.append(current_subarray)
            current_subarray = [num]

    subarrays.append(current_subarray)  # Append the last subarray
    return subarrays

# MERGE CONTEXT IF THEY ARE THE SERIAL CONTEXT
def merge_contexts(passages):
    passages_sorted_by_id = sorted(passages, key=lambda x: x["id"], reverse=False)
    # psg_texts = [x["passage"].strip("Title: ").strip(x["title"]).strip() 
    #              for x in passages_sorted_by_id]
    # print(passages_sorted_by_id)
    if not len(passages_sorted_by_id):
        return []
    psg_ids = [x["id"] for x in passages_sorted_by_id]
    consecutive_ids = extract_consecutive_subarray(psg_ids)
    merged_contexts = []
    consecutive_psgs = []
    b = 0
    for ids in consecutive_ids:
        psgs = passages_sorted_by_id[b:b+len(ids)]
        psg_texts = [x["passage"].strip("Title: ").strip(x["title"]).strip() 
                     for x in psgs]
        merged = f"Title: {psgs[0]['title']}\n\n" + " ".join(psg_texts)
        b = b+len(ids)
        merged_contexts.append(dict(
            title=psgs[0]['title'], 
            passage=merged,
            score=max([x["combined_score"] for x in psgs]),
            merged_from_ids=ids
        ))
    return merged_contexts

def discard_contexts(passages):
    sorted_passages = sorted(passages, key=lambda x: x["score"], reverse=False)
    if len(sorted_passages) == 1:
        return sorted_passages
    else:
        shortened = deepcopy(sorted_passages)
        for i in range(len(sorted_passages) - 1):
            current, next = sorted_passages[i], sorted_passages[i+1]
            if next["score"] - current["score"] >= 0.05:
                shortened = sorted_passages[i+1:]
        return shortened

def expand_context(passage, word_window=60, n_sent=3):
    # psg_id = passage["id"]
    merged_from_ids = passage["merged_from_ids"]
    title = passage["title"]
    prev_id = merged_from_ids[0] - 1
    next_id = merged_from_ids[-1] + 1
    strip_title = lambda x: x["passage"].strip(f"Title: {x['title']}\n\n")
    
    texts = []
    if prev_id in range(0, len(meta_corpus)):
        prev_psg = meta_corpus[prev_id]
        if prev_psg["title"] == title: 
            prev_text = strip_title(prev_psg)
            # prev_text = " ".join(prev_text.split()[-word_window:])
            prev_text = " ".join(sent_tokenize(prev_text)[-n_sent:])
            texts.append(prev_text)
            
    texts.append(strip_title(passage))
    
    if next_id in range(0, len(meta_corpus)):
        next_psg = meta_corpus[next_id]
        if next_psg["title"] == title: 
            next_text = strip_title(next_psg)
            # next_text = " ".join(next_text.split()[:word_window])
            next_text = " ".join(sent_tokenize(next_text)[:n_sent])
            texts.append(next_text)

    expanded_text = " ".join(texts)
    expanded_text = f"{expanded_text}"
    new_passage = deepcopy(passage)
    new_passage["passage"] = expanded_text
    return new_passage

def expand_contexts(passages, word_window=60, n_sent=3):
    new_passages = [expand_context(passage) for passage in passages]
    return new_passages
    
def collapse(passages):
    new_passages = deepcopy(passages)
    titles = {}
    for passage in new_passages:
        title = passage["title"]
        if not titles.get(title):
            titles[title] = [passage]
        else:
            titles[title].append(passage)
    best_passages = []
    for k, v in titles.items():
        best_passage = max(v, key= lambda x: x["score"])
        best_passages.append(best_passage)
    return best_passages

# %% [markdown]
# Note that, with our current chunking strategy, each chunk is a passage of exact 150 words (separated by space), not a comprehensive paragraph. The following function will transform retrieved chunks into whole paragraphs. This function also does some heuristics to expand the context window and discard seem-to-be irrelevant contexts.

# %%
def smooth_contexts(passages):
    """Make the context fed to the LLM better.
    Args:
        passages (list): Chunks retrieved from BM25 + semantic retrieval. 
        
    Returns:
        list: List of whole paragraphs, usually will be more relevant to the initital question.
    """
    # 1. If consecutive chunks are rertieved, merge them into one big chunk to ensure the continuity.
    merged_contexts = merge_contexts(passages)
    # 2. A heuristic to discard irrelevevant contexts. 
    # It seems to be better to only keep what are elevant so that the model can focus.
    # Also this reduce #tokens LLM has to read.
    shortlisted_contexts = discard_contexts(merged_contexts)
    # 3. Another heuristic. this step is to take advantage of long context understanding of the LLM.
    # In many cases, the retrieved passages are just consecutive words, not a comprehensive paragraph.
    # This is to expand the passage to the whole paragraph that surrounds it. 
    # My intuition about this is that whole paragraph will add necessary and relevant information.
    expanded_contexts = expand_contexts(shortlisted_contexts)
    # 4. Now after all the merging and expanding, if what are left for us is more than one paragraphs
    # from the same wiki page, then we will only take paragraph with highest retrieval score.
    collapsed_contexts = collapse(expanded_contexts)
    return collapsed_contexts

# %%
## I encourage you to investigate each smoothing step using the following example
## to understand the benefit of them. 
## You will see that after each step, we will obtain "better" contexts.

question = "Các biện pháp phòng trừ bệnh khô cành khô quả cho cây cà phê?"
top_passages = retrieve(question, topk=3)
merged_contexts = merge_contexts(top_passages)
shortlisted_contexts = discard_contexts(merged_contexts)
expanded_contexts = expand_contexts(shortlisted_contexts)
collapsed_contexts = collapse(expanded_contexts)

# %%
## Uncomment each of these variable to see the differences.

# top_passages
# merged_contexts
# shortlisted_contexts
# expanded_contexts
# collapsed_contexts

# %% [markdown]
# ## Generate

# %%
from transformers import GenerationConfig, TextStreamer
from transformers import AutoModelForCausalLM, AutoTokenizer

import torch
import os
os.environ['HF_HOME'] = "/media/user123456/D2/tmp/cache/huggingface"
# os.environ['HUGGINGFACE_HUB_CACHE'] = "/media/user123456/D2/tmp/cache/huggingface/hub"
torch_dtype = torch.bfloat16
model_id = "Viet-Mistral/Vistral-7B-Chat"
device = "cuda:1"
cache_dir = "/media/user123456/D2/tmp/cache/huggingface/hub"
tokenizer = AutoTokenizer.from_pretrained(model_id, use_cache=True,
                                           cache_dir=cache_dir
                                        )
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.bfloat16, # change to torch.float16 if you're using V100
    # device_map="auto",
    use_cache=True,
    cache_dir=cache_dir
).eval().to(device)

# model = model.eval().to(device)

# %%
def generate(prompt, max_new_tokens=1024, tempearature = 0, top_p = 0):
    """Text completion with a given prompt. In other words, give answer to your question.
    Args:
        prompt (str): Basically <instruction> + <question> + <retrieved_context>
        generation_config (not existed yet): For now, please manually tweak hyperparameters
        for generation in the `generation_config` below. Uncomment necessary arguments as you wish.
    Returns:
        list: an answer to the question within the prompt.
    """
    device = "cuda:1"
    # print(device)
    input_ids = tokenizer(prompt, return_tensors="pt")["input_ids"].to(device)
    model.eval()
    with torch.no_grad():
        generation_config = GenerationConfig(
            repetition_penalty=1.13,
            max_new_tokens=max_new_tokens,
            temperature=tempearature,
            top_p=top_p,
            # top_k=20,
            # bos_token_id=tokenizer.bos_token_id,
            eos_token_id=tokenizer.eos_token_id,
            # eos_token_id=0, # for open-end generation.
            pad_token_id=tokenizer.pad_token_id,
            do_sample=False,
            use_cache=True,
            return_dict_in_generate=True,
            output_attentions=False,
            output_hidden_states=False,
            output_scores=False,
        )
        streamer = TextStreamer(tokenizer, skip_prompt=True)
        generated = model.generate(
            inputs=input_ids,
            generation_config=generation_config,
            streamer=streamer,
        )

    gen_tokens = generated["sequences"].cpu()[:, len(input_ids[0]):].to(device)
    output = tokenizer.batch_decode(gen_tokens)[0]
    output = output.split(tokenizer.eos_token)[0]
    return output.strip()

# %%
prompt_template = (
"<s>[INST] <<SYS>>\n"
"<</SYS>> \n\n"
"""
<context>
{context}
</context>
Question: {question} [/INST]"""
)

def get_prompt(question, contexts, prompt_template=prompt_template):
    context = "\n\n".join([f" {x['passage']}" for i, x in enumerate(contexts)])
    # instruction = 'As an intelligent AI model, your task is to analyze and integrate information from multiple contexts given below in order to answer questions and provide citations.'
    prompt = prompt_template.format(
        # instruction=instruction,
        context=context,
        question = question,
        output=''
    )
    return prompt

# %%
# prompt_template = (
# "<s>[INST] <<SYS>>\n"
# "<</SYS>> \n\n"
# "{input} [/INST]"
# )

# def get_prompt(question, contexts, prompt_template=prompt_template):
#     context = "\n\n".join([f" {x['passage']}" for i, x in enumerate(contexts)])
#     # instruction = 'As an intelligent AI model, your task is to analyze and integrate information from multiple contexts given below in order to answer questions and provide citations.'

#     input = f"""
#     <context>
#     {context}
#     </context>
#     Question: {question}
#     """
#     prompt = prompt_template.format(
#         # instruction=instruction,
#         input=input,
#         output=''
#     )
#     return prompt

# %%
question = "Thủ đô của Việt Nam"
get_prompt(question,"")

# %% [markdown]
# ### PROMPT SAMPLE 1:

# %%
prompt_template_1 = (
"<s>[INST] <<SYS>>\n"
"Bạn là một trợ lí Tiếng Việt trả lời câu hỏi nhiệt tình và trung thực chỉ dựa vào thông tin được cho.\n"
"Bạn chỉ dựa vào nội dung của [DOCUMENT] được cung cấp để trả lời [QUESTION]. Đừng thêm bất kỳ thông tin cá nhân hoặc thông tin từ bên ngoài vào câu trả lời của bạn.\n"
"Bạn trả lời đúng trọng tâm của câu hỏi và tránh trả lời quá dài dòng hoặc không liên quan.\n"
# "Câu trả lời của bạn không nên chứa bất kỳ nội dung gây hại, phân biệt chủng tộc, phân biệt giới tính, độc hại, nguy hiểm hoặc bất hợp pháp nào. Hãy đảm bảo rằng các câu trả lời của bạn không có thiên kiến xã hội và mang tính tích cực. Nếu một câu hỏi không có ý nghĩa hoặc không hợp lý về mặt thông tin, hãy giải thích tại sao thay vì trả lời một điều gì đó không chính xác."
"""Hãy trả về kết quả là "Tôi không biết trả lời câu hỏi này" nếu bạn không chắc chắn về đáp án của mình.\n"""
"<</SYS>> \n\n"
"""
<context>
{context}
</context>
Question: {question} [/INST]"""
)

# %%
print(prompt_template_1)

# %% [markdown]
# ### PROMPT SAMPLE 2:

# %%
prompt_template_2 = (
"<s>[INST] <<SYS>>\n"
"Bạn là một trợ lí Tiếng Việt trả lời câu hỏi nhiệt tình và trung thực.\n"
"Nhiệm vụ chính của bạn là trả lời câu hỏi chỉ dựa vào đoạn thông tin được đưa ra.\n"
"Giữ cái câu trả lời ngắn gọn và súc tích.\n"
# "Câu trả lời của bạn đúng trọng tâm của câu hỏi và tránh trả lời quá dài dòng hoặc không liên quan.\n"
# "Câu trả lời của bạn không nên chứa bất kỳ nội dung gây hại, phân biệt chủng tộc, phân biệt giới tính, độc hại, nguy hiểm hoặc bất hợp pháp nào. Hãy đảm bảo rằng các câu trả lời của bạn không có thiên kiến xã hội và mang tính tích cực. Nếu một câu hỏi không có ý nghĩa hoặc không hợp lý về mặt thông tin, hãy giải thích tại sao thay vì trả lời một điều gì đó không chính xác."
"""Hãy trả về kết quả là "Tôi không biết trả lời câu hỏi này" nếu bạn không chắc chắn về câu trả lời của mình.\n"""
"""Hãy trả về kết quả là "Tôi không biết trả lời câu hỏi này" nếu đoạn thông tin được đưa ra không có dữ liệu liên quan đến câu hỏi.\n"""
"<</SYS>> \n\n"
"""
<context>
{context}
</context>
Question: {question} [/INST]"""
)

# %%
top_passages
# Out:
# []

# %%
## Let's see how a prompt fed to the LLM looks like
question = "Thủ đô của Hàn Quốc"
thresh_combined= 0.65
top_p = 0
score_evaluate = 'combined_score'
top_passages = retrieve(question, topk=5,score_evaluate=score_evaluate, threshold_score = thresh_combined)
# smoothed_contexts = smooth_contexts(top_passages)
prompt = get_prompt(question, top_passages, prompt_template_3)
output = generate(prompt, tempearature=0, top_p= top_p)
print(prompt)
# print(output)
# Out:
#  <answer>Thủ đô của Hàn Quốc là Seoul.</answer> </s>
# <s>[INST] <<SYS>>
# Bạn là một trợ lí Tiếng Việt trả lời câu hỏi nhiệt tình và trung thực.
# Bạn sẽ chỉ trả lời các câu hỏi của người dùng bằng thông tin được cung cấp. Bạn sẽ tuân thủ các quy tắc sau:
# - Bạn không bao giờ nói dối hay bịa ra những câu trả lời không được nêu rõ ràng trong thông tin được cung cấp.
# - Nếu bạn không chắc chắn về câu trả lời hoặc câu hỏi không có rõ ràng trong thông tin được cung cấp, bạn sẽ nói: "Tôi xin lỗi, tôi không biết phải trợ giúp điều đó như thế nào.".
# - Bạn luôn giữ câu trả lời ngắn gọn, phù hợp và súc tích.<</SYS>>
#
#
# <context>
#
# </context>
# <question>: Thủ đô của Hàn Quốc </question> [/INST]

# %%
output = generate(prompt)

# %%
# import torch
# from transformers import AutoModelForCausalLM, AutoTokenizer

# system_prompt = "Bạn là một trợ lí Tiếng Việt nhiệt tình và trung thực. Hãy luôn trả lời một cách hữu ích nhất có thể, đồng thời giữ an toàn.\n"
# system_prompt += "Câu trả lời của bạn không nên chứa bất kỳ nội dung gây hại, phân biệt chủng tộc, phân biệt giới tính, độc hại, nguy hiểm hoặc bất hợp pháp nào. Hãy đảm bảo rằng các câu trả lời của bạn không có thiên kiến xã hội và mang tính tích cực."
# system_prompt += "Nếu một câu hỏi không có ý nghĩa hoặc không hợp lý về mặt thông tin, hãy giải thích tại sao thay vì trả lời một điều gì đó không chính xác. Nếu bạn không biết câu trả lời cho một câu hỏi, hãy trẳ lời là bạn không biết và vui lòng không chia sẻ thông tin sai lệch."

# tokenizer = AutoTokenizer.from_pretrained('Viet-Mistral/Vistral-7B-Chat')
# model = AutoModelForCausalLM.from_pretrained(
#     'Viet-Mistral/Vistral-7B-Chat',
#     torch_dtype=torch.bfloat16, # change to torch.float16 if you're using V100
#     device_map="auto",
#     use_cache=True,
# )

# conversation = [{"role": "system", "content": system_prompt }]
# def generate(prompt, max_new_tokens=1024):
#     human = input("Human: ")
#     if human.lower() == "reset":
#         conversation = [{"role": "system", "content": system_prompt }]
#         print("The chat history has been cleared!")
#         continue

#     conversation.append({"role": "user", "content": human })
#     input_ids = tokenizer.apply_chat_template(conversation, return_tensors="pt").to(model.device)
    
#     out_ids = model.generate(
#         input_ids=input_ids,
#         max_new_tokens=768,
#         do_sample=True,
#         top_p=0.95,
#         top_k=40,
#         temperature=0.1,
#         repetition_penalty=1.05,
#     )
#     assistant = tokenizer.batch_decode(out_ids[:, input_ids.size(1): ], skip_special_tokens=True)[0].strip()
#     print("Assistant: ", assistant) 
#     conversation.append({"role": "assistant", "content": assistant })

# %%
## Let's test what the LLM would generate given a question and its context via a prompt.
output = generate(prompt)

# %% [markdown]
# Not the best but pretty accurate.

# %% [markdown]
# ## End-to-End RAG

# %% [markdown]
# It's almost done. Now let's try a simple RAG pipeline with our Wikipedia corpus.

# %%
def rag(question, topk=3, score_evaluate='combined_score', threshold_score = 0.6, top_p = 0, prompt_template = prompt_template):
    top_passages = retrieve(question, topk=topk,score_evaluate=score_evaluate, threshold_score = threshold_score)
    if not len(top_passages):
        print("Cannot find document revelance")
        return {
        "retrieved_context": None,
        "generated_answer": "Không thể trả lời câu hỏi vì không tìm thấy thông tin liên quan trong kho dữ liệu"
    }
    smoothed_contexts = smooth_contexts(top_passages)
    # print("_____")
    # print(smoothed_contexts)
    retrieved_context = "\n\n".join([f"Context [{i+1}]: {x['passage']}" 
                    for i, x in enumerate(smoothed_contexts)])
    prompt = get_prompt(question, smoothed_contexts, prompt_template)
    output = generate(prompt, tempearature=0, top_p= top_p)
    result = {
        "retrieved_context": retrieved_context,
        "generated_answer": output.replace("</s>", "")
    }
    return result

# %%
thresh_combined= 0.6
top_p = 0
score_evaluate = 'combined_score'
topk = 5
questions = [
    "Cầu thủ nào dành nhiều quả bóng vàng nhất?",
    "Thành phố nào là thủ đô của Việt Nam?",
    "Công dụng của cây nha đam đối với sức khỏe?",
    "Khi nào là thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê?",
    "Tại sao 2Nông hỗ trợ truy xuất nguồn gốc sản phẩm?"
]
for question in questions:
    print(f"Câu hỏi: {question}")
    output = rag(question, topk=topk, score_evaluate=score_evaluate, threshold_score=thresh_combined, top_p=top_p, prompt_template =prompt_template_2)
    # print(output)
    print("---" * 30)
# Out:
# Câu hỏi: Cầu thủ nào dành nhiều quả bóng vàng nhất?
# Cannot find document revelance
# ------------------------------------------------------------------------------------------
# Câu hỏi: Thành phố nào là thủ đô của Việt Nam?
# Cannot find document revelance
# ------------------------------------------------------------------------------------------
# Câu hỏi: Công dụng của cây nha đam đối với sức khỏe?
#  Công dụng của cây nha đam bao gồm sát khuẩn, chống lão hóa, giảm sưng, viêm, bảo vệ đường ruột, dạ dày, cải thiện chất lượng giấc ngủ và hỗ trợ não bộ. </s>
# ------------------------------------------------------------------------------------------
# Câu hỏi: Khi nào là thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê?
#  Thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê là trước khi tiến hành bón phân và trước khi mùa mưa bắt đầu. </s>
# ------------------------------------------------------------------------------------------
# Câu hỏi: Tại sao 2Nông hỗ trợ truy xuất nguồn gốc sản phẩm?
#   </s>
# ------------------------------------------------------------------------------------------

# %%
import pandas as pd
# test_df = pd.read_csv("/media/user123456/D2/chatbot/langchain_rag/scripts/evaluate/embeddings_models/vinai__phobert-base-v2_vncore_segment/20_vinai__phobert-base-v2_vncore_segment_256_20_cosine.csv", sep="|")
test_evaluate = pd.read_excel('evaluat_dataset_3.xlsx' ).drop(['Unnamed: 0'], axis=1)[['question', 'answer', 'source_doc']]

# %% [markdown]
# ### PROMPT TEMPLATE 1:

# %%
prompt_template_1 = (
"<s>[INST] <<SYS>>\n"
"Tôi là  một nhân viên hỗ trợ khách hàng rất tốt bụng và nhiệt tình, thích giúp đỡ khách hàng.\n"
"Tôi sẽ chỉ trả lời các câu hỏi của người dùng bằng <context> được cung cấp. Tôi sẽ tuân thủ các quy tắc sau:\n"
"- Tôi là một người tốt bụng và hữu ích, là nhân viên hỗ trợ khách hàng tốt nhất hiện nay\n"
"- Tôi không bao giờ nói dối hay bịa ra những câu trả lời không được nêu rõ ràng trong <context>\n"
"""- Nếu tôi không chắc chắn về câu trả lời hoặc câu trả lời không có rõ ràng trong <context>, tôi sẽ nói: "Tôi xin lỗi, tôi không biết phải trợ giúp điều đó như thế nào.\n" """
"- Tôi luôn giữ câu trả lời ngắn gọn, phù hợp và súc tích."
"<</SYS>> \n\n"
"""
<context>
{context}
</context>
Question: {question} [/INST]"""
)

# %% [markdown]
# ### PROMPT TEMPLATE 2:

# %%
prompt_template_2 = (
"<s>[INST] <<SYS>>\n"
"Bạn là một trợ lí Tiếng Việt trả lời câu hỏi nhiệt tình và trung thực.\n"
"Nhiệm vụ chính của bạn là trả lời câu hỏi chỉ dựa vào đoạn thông tin được đưa ra.\n"
"Giữ cái câu trả lời ngắn gọn và súc tích.\n"
# "Câu trả lời của bạn đúng trọng tâm của câu hỏi và tránh trả lời quá dài dòng hoặc không liên quan.\n"
# "Câu trả lời của bạn không nên chứa bất kỳ nội dung gây hại, phân biệt chủng tộc, phân biệt giới tính, độc hại, nguy hiểm hoặc bất hợp pháp nào. Hãy đảm bảo rằng các câu trả lời của bạn không có thiên kiến xã hội và mang tính tích cực. Nếu một câu hỏi không có ý nghĩa hoặc không hợp lý về mặt thông tin, hãy giải thích tại sao thay vì trả lời một điều gì đó không chính xác."
"""Hãy trả về kết quả là "Tôi không biết trả lời câu hỏi này" nếu bạn không chắc chắn về câu trả lời của mình.\n"""
"""Hãy trả về kết quả là "Tôi không biết trả lời câu hỏi này" nếu đoạn thông tin được đưa ra không có dữ liệu liên quan đến câu hỏi.\n"""
"<</SYS>> \n\n"
"""
<context>
{context}
</context>
Question: {question} [/INST]"""
)

# %% [markdown]
# ### PROMPT TEMPLATE 3:

# %%
prompt_template_3 = (
"<s>[INST] <<SYS>>\n"
"Bạn là một trợ lí Tiếng Việt trả lời câu hỏi nhiệt tình và trung thực.\n"
# "Bạn sẽ trả lời các câu hỏi chỉ bằng cách sử dụng thông tin được cung cấp và tuân theo các quy tắc.\n"
# """[QUY TẮC]:"""
"""Bạn sẽ chỉ trả lời các câu hỏi của người dùng bằng thông tin được cung cấp. Bạn sẽ tuân thủ các quy tắc sau:
- Bạn không bao giờ nói dối hay bịa ra những câu trả lời không được nêu rõ ràng trong thông tin được cung cấp.
- Nếu bạn không chắc chắn về câu trả lời hoặc câu hỏi không có rõ ràng trong thông tin được cung cấp, bạn sẽ nói: "Tôi xin lỗi, tôi không biết phải trợ giúp điều đó như thế nào.".
- Bạn luôn giữ câu trả lời ngắn gọn, phù hợp và súc tích."""
"<</SYS>>  \n\n" 
"""
<context>
{context}
</context>
<question>: {question} </question> [/INST]"""
)

# %% [markdown]
# ## EXECUTE

# %%
folder_save_evaluate = "./evaluate/"
prompt_name = "prompt_template_3_cosine_evaluate"    
prompt_template_use = prompt_template_3
folder_save_result_prompt = folder_save_evaluate + prompt_name + "/"
os.makedirs(folder_save_result_prompt, exist_ok=True)
with open(folder_save_result_prompt + "prompt_template.txt", 'w') as f:
    f.write(prompt_template_use)
tempearature = 0
top_p = 0
score_evaluate = 'cosine_score'
# topk = 5
for topk in [5]:
    for thresh_combined in [0.5, 0.6, 0.65, 0.7, 0.75, 0.8]:
        print(f"Top k: {topk}  ----- Threshold: {thresh_combined}")
        test_df = test_evaluate.copy()
        test_df['vietmistal_result'] = test_df['question'].apply(lambda x: rag(x, topk=topk, score_evaluate=score_evaluate, threshold_score=thresh_combined, top_p=top_p,prompt_template=prompt_template_use))
        test_df= test_df.join(pd.DataFrame(test_df['vietmistal_result'].values.tolist()))
        test_df.to_excel(folder_save_result_prompt + f"vietmistal_result_threshole_{thresh_combined}_tempearature_{tempearature}_top{topk}.xlsx", index=False)
        print("________"*10)
# Out:
# Top k: 5  ----- Threshold: 0.5
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
#  <answer>Nha đam có tác dụng sát khuẩn, chống lão hóa, giảm sưng, viêm,... nên được ứng dụng rộng rãi trong các phương pháp chăm sóc và làm đẹp da. Ngoài ra chúng còn có khả năng bảo vệ đường ruột, dạ dày.</answer> </s>
#  Để chăm sóc đúng cách cho cây lan Vanda, hãy đảm bảo rằng chúng nhận được nhiệt độ từ 25 - 30 độ C, độ ẩm khoảng 70-80%. Tưới nước đều đặn, đặc biệt là trong thời kỳ khô hạn. Vì đây là giống ưa sáng nên chúng cần ánh sáng mạnh mẽ để nở hoa. Ngoài ra, duy trì hệ thống thoát nước thích hợp và bón phân cân đối mỗi tuần một lần cũng góp phần tạo môi trường lý tưởng cho cây phát triển khỏe mạnh. </s>
#  Để phòng trừ côn trùng và nấm bệnh trên cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây, ảnh hưởng trực tiếp đến chất lượng và khả năng đậu trái. Do đó, nên tập trung cẩn thận vào các biện pháp này để đảm bảo kết quả tốt nhất cho vườn cây ăn quả của bạn. </s>
#  Để trồng và chăm sóc cây chu đinh lan, hãy làm theo hướng dẫn sau đây :
#
# 1. Chọn loại đất thích hợp: Chu đinh lan ưa đất tơi xốp, thoát nước tốt và duy trì độ ẩm khoảng 60-70 %. Đảm bảo rằng đất có hệ thống thoát nước đầy đủ để ngăn ngừa rễ cây bị ngập lụt.
#
# 2. Nhân giống: Có thể nhân giống cây chu đinh lan bằng phương pháp tách bụi. Sau khi đã trồng cây mẹ được một thời gian, bạn có thể bắt đầu tách cây con. Sử dụng một tay để giữ bụi lan, đồng thời sử dụng hỗn hợp đất trồng trong chậu. Phủ lên trên 1/3 củ trước khi đặt nó trở lại vị trí cũ. Vì củ lan rất dễ bị thối nên tránh chôn sâu hơn nữa. Việc tách cành không yêu cầu nhiều củ như đối với các loài lan khác.
#
# 3. Tưới nước: Mặc dù chu đinh lan có thể tồn tại mà không cần tưới nhiều nước, nhưng việc tưới thường xuyên vẫn khuyến khích cây ra hoa nhiều và liên tục. Hãy cố gắng tưới mỗi tuần hai lần.
#
# 4. Ánh nắng mặt trời: Cây sinh trưởng tốt trong điều kiện ánh sáng mặt trời toàn phần, vì vậy hãy đảm bảo cây nhận ít nhất tám giờ chiếu sáng trực tiếp mỗi ngày.
#
# 5. Nhiệt độ: Chu đinh lan có thể chịu được cả nhiệt độ cao lẫn lạnh, miễn sao đừng quá khắc nghiệt. Duy trì mức nhiệt độ vừa phải quanh năm.
#
# Bằng cách làm theo những nguyên tắc đơn giản này, bạn có thể nuôi dưỡng thành công cây chu đinh lan và tận hưởng vẻ đẹp rực rỡ cùng hương thơm ngọt ngào của nó! </s>
#  Để chăm sóc hoa lan Cattleya, hãy chú ý đến nhu cầu ánh sáng, tưới nước và bón phân của nó. Đảm bảo rằng môi trường sống của cây nhận đủ lượng ánh nắng trực tiếp, vì đây là yếu tố quan trọng đối với sự phát triển và nở hoa của cây. Tưới nước cho cây đều đặn, tránh tưới quá nhiều nước dẫn đến thối rễ. Bón phân cân đối mỗi tháng một lần trong mùa sinh trưởng (mùa xuân và hè) để thúc đẩy tăng trưởng và nở hoa tối ưu. Theo dõi chặt chẽ cây để phát hiện sớm các vấn đề tiềm ẩn như côn trùng xâm nhập hoặc nhiễm nấm, đồng thời xử lý kịp thời để duy trì sức khỏe tổng quát của cây. </s>
#  Để điều trị sâu ăn lá hoặc bám vào cây hoa Lan Cattleya, hãy xem xét việc phun thuốc diệt sâu bệnh lên cây hoặc loại bỏ chúng nếu có thể. Ngoài ra, kiểm tra và cắt bỏ bất kỳ phần nào của cây đã chết hoặc bị hư hại do sâu bệnh gây ra. Điều quan trọng cũng là duy trì môi trường sạch sẽ và vệ sinh để ngăn chặn vấn đề sâu bệnh tái diễn. Tham khảo ý kiến chuyên gia làm vườn địa phương hoặc nhà cung cấp sản phẩm chăm sóc cây trồng để nhận thêm hướng dẫn cụ thể dựa trên nhu cầu cá nhân của cây. </s>
#  Truy xuất nguồn gốc sản phẩm rất cần thiết để đảm bảo an toàn vệ sinh thực phẩm và uy tín thương mại. Bằng cách hỗ trợ truy xuất nguồn gốc sản phẩm, 2Nông giúp nông dân theo dõi lịch sử trồng trọt, kiểm soát chất lượng và xác nhận nguồn gốc nguyên liệu. Điều này làm tăng niềm tin của khách hàng đối với sản phẩm, thúc đẩy tiêu thụ nội địa và xuất khẩu. Ngoài ra, việc truy xuất nguồn gốc còn giúp ngăn chặn gian lận thương mại và vi phạm bản quyền, cuối cùng dẫn đến cải thiện quản trị chuỗi cung ứng tổng thể. </s>
#  Để bổ sung chất hữu cơ cho đất sau thu hoạch đối với vườn cây ăn trái, bạn có thể áp dụng các phương pháp sau đây:
# 1. Bổ sung dinh dưỡng và chất hữu cơ cho đất: Sử dụng phân chuồng ủ hoai mục, phân xanh, phân trùn quế, đạm cá, phân NPK hữu cơ,... để nâng cao hàm lượng dinh dưỡng và chất hữu cơ trong đất.
# 2. Che phủ bằng cách để cỏ hoặc sử dụng các nguyên liệu hữu cơ: Dùng cỏ hoặc các loại nguyên liệu khác như rơm rạ, cành lá khô, tàn dư hoa màu, bèo lục bình, thân lá chuối, trấu,... để che phủ bề mặt đất. Các nguyên liệu này sẽ bị vi sinh vật đất phân hủy thành mùn, góp phần cải thiện cấu trúc đất và khả năng giữ ẩm.
# 3. Bổ sung vi sinh vật vào đất để cải tạo đất sau thu hoạch: Áp dụng biện pháp sử dụng phân bón vi sinh nhằm thúc đẩy sự phát triển của quần xã vi sinh vật có ích trong đất, từ đó hỗ trợ chuyển hóa chất hữu cơ thành dạng mà cây trồng dễ tiếp cận hơn. Điều này cũng giúp cân bằng hệ sinh thái vi sinh vật trong đất. </s>
#  Thời điểm tốt nhất để bón đạm cho lúa là trước lúc cấy và lúc cây lúa bắt đầu làm đòng. Không nên bón đạm ngay sau khi cấy và tránh bón đạm khi trời sắp mưa hoặc nắng nóng gay gắt. Bón đạm vào buổi sáng hoặc chiều tối là lý tưởng hơn cả. </s>
#  Để khắc phục nứt trái trên cây trồng, hãy xem xét các bước sau đây:
#
# 1. Kiểm soát lượng nước: Đảm bảo rằng cây nhận đủ nước mà không bị ngập lụt. Điều chỉnh lịch tưới dựa trên điều kiện khí hậu địa phương và yêu cầu cụ thể của loại cây trồng. Tránh tưới quá nhiều nước vì nó có thể góp phần vào sự phát triển của vi khuẩn và nấm.
#
# 2. Bón cân đối: Cung cấp dinh dưỡng đầy đủ cho cây trồng, đặc biệt chú ý đến hàm lượng kali và canxi. Những chất dinh dưỡng này đóng vai trò quan trọng trong cấu trúc tế bào và sức khỏe tổng quát của trái cây. Sử dụng phân bón cân đối theo khuyến cáo của nhà sản xuất.
#
# 3. Loại bỏ hoa đực sớm: Hoa đực tạo ra phấn hoa, nếu không thụ tinh thì chúng trở thành hạt giống ăn vào trái cây. Việc loại bỏ hoa đực sớm giảm thiểu nguy cơ hình thành hạt giống bên trong trái cây, có thể gây áp lực lên da và dẫn đến nứt nẻ.
#
# 4. Bảo vệ khỏi sâu hại: Sâu hại như ruồi đục quả có thể xâm nhập vào trái cây qua vết thương nhỏ, phá vỡ lớp vỏ và góp phần gây nứt nẻ. Thực hành kiểm soát dịch hại thích hợp như sử dụng bẫy dính màu vàng hoặc màng bọc trái cây để ngăn chặn côn trùng tiếp cận trái cây.
#
# 5. Chọn giống kháng: Một số loài cây đã được lai tạo để có khả năng chống lại vấn đề nứt trái tốt hơn. Hãy tìm kiếm các giống này khi chọn mua cây mới.
#
# 6. Theo dõi chặt chẽ: Thường xuyên kiểm tra vườn cây để phát hiện dấu hiệu căng thẳng hoặc tổn thương tiềm ẩn. Can thiệp kịp thời có thể giúp ngăn ngừa nứt trái trước khi xảy ra.
#
# Bằng cách thực hiện các biện pháp phòng ngừa này, bạn có thể giảm đáng kể tỷ lệ nứt trái trên cây trồng và đảm bảo thu hoạch tối ưu. </s>
#  Để khắc phục hiện tượng xơ đen trên mít, cần áp dụng đồng thời hai biện pháp chính: bảo vệ hoa khỏi mưa ướt và tăng cường khả năng hấp thụ canxi của cây. Đầu tiên, sử dụng màng nilon để tạo mái che chống mưa lên phần hoa đực đang nở nhằm ngăn chặn sự xâm nhập của vi khuẩn gây bệnh. Tiếp theo, bón phân chứa canxi hòa tan dạng chelate (Ca - Chelate ), cả qua đường lá lẫn rễ, đặc biệt tập trung vào giai đoạn trước và sau khi ra hoa. Định kỳ lặp lại việc phun xịt mỗi 2 tháng để duy trì mức độ canxi tối ưu hỗ trợ sức khỏe tổng thể của cây trồng. Bằng cách kết hợp các chiến lược này, bạn có thể kiểm soát hiệu quả vấn đề xơ đen ở mít và thúc đẩy sản lượng trái cây chất lượng cao hơn. </s>
#  Để đảm bảo cà phê ra hoa đồng loạt, quan trọng là xác định thời điểm tưới nước thích hợp dựa trên điều kiện thời tiết địa phương, loại đất và sức khỏe tổng thể của cây trồng. Khi nhận thấy sự hình thành nụ hoa đầy đủ dưới dạng mỏ sẻ tại đốt ngoài cùng của các cành, hãy bắt đầu quá trình tưới nước. Tưới nước đúng cách và đều đặn trong đợt đầu tiên rất quan trọng đối với kết quả mong muốn này. </s>
#  Để phòng trị sâu vẽ bùa trên cây cam, sử dụng phương pháp phun loại thuốc lưu dẫn hoặc quét thuốc lưu dẫn ở giai đoạn mới nhú đọt non (bằng hạt gạo). </s>
#  Để phòng trừ bệnh khô cành khô quả ở cây cà phê, nên áp dụng tổng hợp các biện pháp như trồng cây che bóng, cây ăn quả với mật độ hợp lý, bón phân đầy đủ, kiểm tra vườn cây thường xuyên, cắt bỏ quả, cành bị gây hại nặng, đồng thời sử dụng một số loại thuốc hóa học khi cần thiết. </s>
#  Đối với cây hồ tiêu trong mô hình trồng hồ tiêu xen cà phê, lượng nước tưới khuyến nghị là khoảng 100 - 120 lít nước cho mỗi gốc/lần, hoặc có thể tưới tiết kiệm với khoảng 80 - 100 lít nước cho mỗi gốc/lần. Tưới 4 lần, mỗi chu kỳ tưới cách nhau 25 - 30 ngày. </s>
#  Để chăm sóc cây sau khi thu hoạch sầu riêng, bà con cần thực hiện vệ sinh gốc cây, tỉa cành, cắt tỉa cành và bón phân. Những bước này rất quan trọng để khôi phục sức khỏe của cây và chuẩn bị nó cho mùa vụ tiếp theo. </s>
#  Không, chuối rẽ quạt không phải là loại chuối. Nó thuộc họ Strelitziaceae khác với họ Musaceae mà chuối thuộc về. </s>
#  Tên gọi tiếng Việt của loài dừa nước là dừa lá. </s>
#  <answer>Tên khoa học của cây đủng đỉnh là Caryota mitis.</answer> </s>
#  Thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê là trước khi tiến hành bón phân và trước khi mùa mưa bắt đầu. Điều này đảm bảo rằng cây nhận đủ ánh sáng mặt trời và dinh dưỡng để phát triển khỏe mạnh và sản xuất hạt cà phê chất lượng cao hơn. </s>
#  <answer>Sản lượng lúa thu hoạch năm 2022 của Việt Nam ước đạt 42,66 triệu tấn.</answer> </s>
# Cannot find document revelance
#  Các cành không mang trái, cành già yếu, cành bị nhiễm bệnh nên được loại bỏ vì chúng góp phần vào sự phát triển của sâu bệnh hại, cản trở ánh sáng mặt trời tiếp cận cây trồng và tiêu thụ tài nguyên mà lẽ ra có thể dành cho sản xuất quả khỏe mạnh hơn. Bằng cách loại bỏ những cành này, khu vườn nhận được nhiều ánh nắng mặt trời hơn, tăng cường lưu thông không khí và thúc đẩy sức khỏe tổng thể của cây. Điều này cũng hỗ trợ duy trì môi trường lành mạnh cho toàn bộ hệ thống cây cối. </s>
#  Để chăm sóc đúng cách cây lan chi, hãy đảm bảo rằng nó nhận được ánh sáng mặt trời gián tiếp, chẳng hạn như dưới tán cây khác hoặc gần cửa sổ với rèm che. Giữ đất ẩm nhưng tránh tưới quá nhiều nước; nước mưa hoặc nước cất là lý tưởng nhất. Cây thích đất giàu chất hữu cơ, thoáng khí với độ pH từ 6-7,5. Cắt tỉa lá vàng hoặc hư hỏng để thúc đẩy sự phát triển khỏe mạnh hơn nữa. </s>
#  Dựa trên ngữ cảnh đã cho, loài thực vật thuộc chi Sầu riêng phổ biến nhất là Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á. </s>
# Cannot find document revelance
#  <answer>Thủy tùng là loài thực vật thuộc họ Măng tây.</answer> </s>
#  <answer>Tre Mạnh Tông được mô tả khoa học lần đầu vào năm 1927.</answer> </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Tôi xin lỗi, nhưng thông tin được cung cấp không đề cập đến bất kỳ chi tiết cụ thể nào liên quan đến số lượng tỉnh thành tại Việt Nam. </s>
#  Để trồng cây chanh dây, hãy làm theo hướng dẫn dưới đây:
# 1. Chọn vị trí thích hợp với ánh nắng mặt trời đầy đủ và đất thoát nước tốt.
# 2. Đào hố sâu khoảng 60 cm và rộng gấp đôi kích thước bầu rễ.
# 3. Đặt cây vào lỗ sao cho cổ rễ ngang bằng với bề mặt đất.
# 4. Lấp đất lên trên gốc cây và ấn nhẹ xuống.
# 5. Tưới nước thật kỹ cho đến khi đất ngấm hết nước.
# 6. Phủ lớp phủ xung quanh thân cây để duy trì độ ẩm và ngăn ngừa cỏ dại mọc.
# 7. Thường xuyên tưới nước cho cây, đặc biệt là trong mùa khô hạn.
# 8. Bón phân cân đối mỗi tháng một lần trong suốt mùa sinh trưởng.
# 9. Cắt tỉa thường xuyên để thúc đẩy sự phát triển mới và loại bỏ cành chết hoặc hư hỏng.
# 10. Bảo vệ cây khỏi sương giá bằng cách che phủ hoặc mang chúng vào bên trong nếu cần thiết. </s>
#  Tôi xin lỗi, tôi không biết phải trợ giúp điều đó như thế nào. </s>
# ________________________________________________________________________________
# Top k: 5  ----- Threshold: 0.6
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
#  Cây nha đam có nhiều lợi ích cho sức khỏe do tính chất kháng khuẩn và chữa bệnh tự nhiên của nó. Nó thường được sử dụng trong các sản phẩm chăm sóc da vì đặc tính dưỡng ẩm và phục hồi của nó. Nha đam cũng đã được chứng minh là hữu ích trong việc thúc đẩy tiêu hóa lành mạnh, hỗ trợ hệ thống miễn dịch và cải thiện chức năng gan. Uống nước ép lô hội tươi có thể tăng cường mức năng lượng và thậm chí giúp kiểm soát cân nặng. Tuy nhiên, quan trọng nhất là tham khảo ý kiến bác sĩ trước khi bắt đầu bất kỳ chế độ ăn uống mới hoặc thay đổi lối sống nào. </s>
#  Để chăm sóc đúng cách cho cây lan Vanda, hãy đảm bảo rằng chúng nhận được nhiệt độ từ 25 - 30 độ C, độ ẩm khoảng 70-80%. Tưới nước đều đặn, đặc biệt là trong thời kỳ khô hạn. Vì đây là giống ưa sáng nên chúng cần ánh sáng mạnh mẽ để nở hoa. Ngoài ra, duy trì hệ thống thoát nước thích hợp và bón phân cân đối mỗi tuần một lần cũng góp phần tạo môi trường lý tưởng cho cây phát triển khỏe mạnh. </s>
#  Để phòng trừ côn trùng và nấm bệnh trên cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây, ảnh hưởng trực tiếp đến chất lượng và khả năng đậu trái. Do đó, nên tập trung cẩn thận vào các biện pháp này để đảm bảo kết quả tốt nhất cho vườn cây ăn quả của bạn. </s>
#  Để trồng và chăm sóc cây chu đinh lan, hãy làm theo hướng dẫn sau đây :
#
# 1. Chọn loại đất thích hợp: Chu đinh lan ưa đất tơi xốp, thoát nước tốt và duy trì độ ẩm khoảng 60-70 %. Đảm bảo rằng đất có hệ thống thoát nước đầy đủ để ngăn ngừa rễ cây bị ngập lụt.
#
# 2. Nhân giống: Có thể nhân giống cây chu đinh lan bằng phương pháp tách bụi. Sau khi đã trồng cây mẹ được một thời gian, bạn có thể bắt đầu tách cây con. Sử dụng một tay để giữ bụi lan, đồng thời sử dụng hỗn hợp đất trồng trong chậu. Phủ lên trên 1/3 củ trước khi đặt nó trở lại vị trí cũ. Vì củ lan rất dễ bị thối nên tránh chôn sâu hơn nữa. Việc tách cành không yêu cầu nhiều củ như đối với các loài lan khác.
#
# 3. Tưới nước: Mặc dù chu đinh lan có thể tồn tại mà không cần tưới nhiều nước, nhưng việc tưới thường xuyên vẫn khuyến khích cây ra hoa nhiều và liên tục. Hãy cố gắng tưới mỗi tuần hai lần.
#
# 4. Ánh nắng mặt trời: Cây sinh trưởng tốt trong điều kiện ánh sáng mặt trời toàn phần, vì vậy hãy đảm bảo cây nhận ít nhất tám giờ chiếu sáng trực tiếp mỗi ngày.
#
# 5. Nhiệt độ: Chu đinh lan có thể chịu được cả nhiệt độ cao lẫn lạnh, miễn sao đừng quá khắc nghiệt. Duy trì mức nhiệt độ vừa phải quanh năm.
#
# Bằng cách làm theo những nguyên tắc đơn giản này, bạn có thể nuôi dưỡng thành công cây chu đinh lan và tận hưởng vẻ đẹp rực rỡ cùng hương thơm ngọt ngào của nó! </s>
#  Để chăm sóc hoa lan Cattleya, hãy chú ý đến nhu cầu ánh sáng, tưới nước và bón phân của nó. Đảm bảo rằng môi trường sống của cây nhận đủ lượng ánh nắng trực tiếp, vì đây là yếu tố quan trọng đối với sự phát triển và nở hoa của cây. Tưới nước cho cây đều đặn, tránh tưới quá nhiều nước dẫn đến thối rễ. Bón phân cân đối mỗi tháng một lần trong mùa sinh trưởng (mùa xuân và hè) để thúc đẩy tăng trưởng và nở hoa tối ưu. Theo dõi chặt chẽ cây để phát hiện sớm các vấn đề tiềm ẩn như côn trùng xâm nhập hoặc nhiễm nấm, đồng thời xử lý kịp thời để duy trì sức khỏe tổng quát của cây. </s>
#  Để điều trị sâu ăn lá hoặc bám vào cây hoa Lan Cattleya, hãy xem xét việc phun thuốc diệt sâu bệnh lên cây hoặc loại bỏ chúng nếu có thể. Ngoài ra, kiểm tra và cắt bỏ bất kỳ phần nào của cây đã chết hoặc bị hư hại do sâu bệnh gây ra. Điều quan trọng cũng là duy trì môi trường sạch sẽ và vệ sinh để ngăn chặn vấn đề sâu bệnh tái diễn. Tham khảo ý kiến chuyên gia làm vườn địa phương hoặc nhà cung cấp sản phẩm chăm sóc cây trồng để nhận thêm hướng dẫn cụ thể dựa trên nhu cầu cá nhân của cây. </s>
#  Truy xuất nguồn gốc sản phẩm rất cần thiết để đảm bảo an toàn vệ sinh thực phẩm và uy tín thương mại. Bằng cách hỗ trợ truy xuất nguồn gốc sản phẩm, 2Nông giúp nông dân theo dõi lịch sử trồng trọt, kiểm soát chất lượng và xác nhận nguồn gốc nguyên liệu. Điều này làm tăng niềm tin của khách hàng đối với sản phẩm, thúc đẩy tiêu thụ nội địa và xuất khẩu. Ngoài ra, việc truy xuất nguồn gốc còn giúp ngăn chặn gian lận thương mại và vi phạm bản quyền, cuối cùng dẫn đến cải thiện quản trị chuỗi cung ứng tổng thể. </s>
#  Để bổ sung chất hữu cơ cho đất sau thu hoạch đối với vườn cây ăn trái, bạn có thể áp dụng các phương pháp sau đây:
# 1. Bổ sung dinh dưỡng và chất hữu cơ cho đất: Sử dụng phân chuồng ủ hoai mục, phân xanh, phân trùn quế, đạm cá, phân NPK hữu cơ,... để nâng cao hàm lượng dinh dưỡng và chất hữu cơ trong đất.
# 2. Che phủ bằng cách để cỏ hoặc sử dụng các nguyên liệu hữu cơ: Dùng cỏ hoặc các loại nguyên liệu khác như rơm rạ, cành lá khô, tàn dư hoa màu, bèo lục bình, thân lá chuối, trấu,... để che phủ bề mặt đất. Các nguyên liệu này sẽ bị vi sinh vật đất phân hủy thành mùn, góp phần cải thiện cấu trúc đất và khả năng giữ ẩm.
# 3. Bổ sung vi sinh vật vào đất để cải tạo đất sau thu hoạch: Áp dụng biện pháp sử dụng phân bón vi sinh nhằm thúc đẩy sự phát triển của quần xã vi sinh vật có ích trong đất, từ đó hỗ trợ chuyển hóa chất hữu cơ thành dạng mà cây trồng dễ tiếp cận hơn. Điều này cũng giúp cân bằng hệ sinh thái vi sinh vật trong đất. </s>
#  Thời điểm tốt nhất để bón đạm cho lúa là trước lúc cấy và lúc cây lúa bắt đầu làm đòng. Không nên bón đạm ngay sau khi cấy và tránh bón đạm khi trời sắp mưa hoặc nắng nóng gay gắt. Bón đạm vào buổi sáng hoặc chiều tối là lý tưởng hơn cả. </s>
#  Để khắc phục nứt trái trên cây trồng, hãy xem xét các bước sau đây:
#
# 1. Kiểm soát lượng nước: Đảm bảo rằng cây nhận đủ nước mà không bị ngập lụt. Điều chỉnh lịch tưới dựa trên điều kiện khí hậu địa phương và yêu cầu cụ thể của loại cây trồng. Tránh tưới quá nhiều nước vì nó có thể góp phần vào sự phát triển của vi khuẩn và nấm.
#
# 2. Bón cân đối: Cung cấp dinh dưỡng đầy đủ cho cây trồng, đặc biệt chú ý đến hàm lượng kali và canxi. Những chất dinh dưỡng này đóng vai trò quan trọng trong cấu trúc tế bào và sức khỏe tổng quát của trái cây. Sử dụng phân bón cân đối theo khuyến cáo của nhà sản xuất.
#
# 3. Loại bỏ hoa đực sớm: Hoa đực tạo ra phấn hoa, nếu không thụ tinh thì chúng trở thành hạt giống ăn vào trái cây. Việc loại bỏ hoa đực sớm giảm thiểu nguy cơ hình thành hạt giống bên trong trái cây, có thể gây áp lực lên da và dẫn đến nứt nẻ.
#
# 4. Bảo vệ khỏi sâu hại: Sâu hại như ruồi đục quả có thể xâm nhập vào trái cây qua vết thương nhỏ, phá vỡ lớp vỏ và góp phần gây nứt nẻ. Thực hành kiểm soát dịch hại thích hợp như sử dụng bẫy dính màu vàng hoặc màng bọc trái cây để ngăn chặn côn trùng tiếp cận trái cây.
#
# 5. Chọn giống kháng: Một số loài cây đã được lai tạo để có khả năng chống lại vấn đề nứt trái tốt hơn. Hãy tìm kiếm các giống này khi chọn mua cây mới.
#
# 6. Theo dõi chặt chẽ: Thường xuyên kiểm tra vườn cây để phát hiện dấu hiệu căng thẳng hoặc tổn thương tiềm ẩn. Can thiệp kịp thời có thể giúp ngăn ngừa nứt trái trước khi xảy ra.
#
# Bằng cách thực hiện các biện pháp phòng ngừa này, bạn có thể giảm đáng kể tỷ lệ nứt trái trên cây trồng và đảm bảo thu hoạch tối ưu. </s>
#  Để khắc phục hiện tượng xơ đen trên mít, cần áp dụng đồng thời hai biện pháp chính: bảo vệ hoa khỏi mưa ướt và tăng cường khả năng hấp thụ canxi của cây. Đầu tiên, sử dụng màng nilon để tạo mái che chống mưa lên phần hoa đực đang nở nhằm ngăn chặn sự xâm nhập của vi khuẩn gây bệnh. Tiếp theo, bón phân chứa canxi hòa tan dạng chelate (Ca - Chelate ), cả qua đường lá lẫn rễ, đặc biệt tập trung vào giai đoạn trước và sau khi ra hoa. Định kỳ lặp lại việc phun xịt mỗi 2 tháng để duy trì mức độ canxi tối ưu hỗ trợ sức khỏe tổng thể của cây trồng. Bằng cách kết hợp các chiến lược này, bạn có thể kiểm soát hiệu quả vấn đề xơ đen ở mít và thúc đẩy sản lượng trái cây chất lượng cao hơn. </s>
#  Để đảm bảo cà phê ra hoa đồng loạt, quan trọng là xác định thời điểm tưới nước thích hợp dựa trên điều kiện thời tiết địa phương, loại đất và sức khỏe tổng thể của cây trồng. Khi nhận thấy sự hình thành nụ hoa đầy đủ dưới dạng mỏ sẻ tại đốt ngoài cùng của các cành, hãy bắt đầu quá trình tưới nước. Tưới nước đúng cách và đều đặn trong đợt đầu tiên rất quan trọng đối với kết quả mong muốn này. </s>
#  Để phòng trị sâu vẽ bùa trên cây cam, sử dụng phương pháp phun loại thuốc lưu dẫn hoặc quét thuốc lưu dẫn ở giai đoạn mới nhú đọt non (bằng hạt gạo). </s>
#  Để phòng trừ bệnh khô cành khô quả ở cây cà phê, nên áp dụng tổng hợp các biện pháp như trồng cây che bóng, cây ăn quả với mật độ hợp lý, bón phân đầy đủ, kiểm tra vườn cây thường xuyên, cắt bỏ quả, cành bị gây hại nặng, đồng thời sử dụng một số loại thuốc hóa học khi cần thiết. </s>
#  Đối với cây hồ tiêu trong mô hình trồng hồ tiêu xen cà phê, lượng nước tưới khuyến nghị là khoảng 100 - 120 lít nước cho mỗi gốc/lần, hoặc có thể tưới tiết kiệm với khoảng 80 - 100 lít nước cho mỗi gốc/lần. Tưới 4 lần, mỗi chu kỳ tưới cách nhau 25 - 30 ngày. </s>
#  Để chăm sóc cây sau khi thu hoạch sầu riêng, bà con cần thực hiện vệ sinh gốc cây, tỉa cành, cắt tỉa cành và bón phân. Những bước này rất quan trọng để khôi phục sức khỏe của cây và chuẩn bị nó cho mùa vụ tiếp theo. </s>
# Cannot find document revelance
# Cannot find document revelance
#  <answer>Tên khoa học của cây đủng đỉnh là Caryota mitis.</answer> </s>
#  Thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê là trước khi tiến hành bón phân và trước khi mùa mưa bắt đầu. Điều này đảm bảo rằng cây nhận đủ ánh sáng mặt trời và dinh dưỡng để phát triển khỏe mạnh và sản xuất hạt cà phê chất lượng cao hơn. </s>
#  <answer>Sản lượng lúa thu hoạch năm 2022 của Việt Nam ước đạt 42,66 triệu tấn.</answer> </s>
# Cannot find document revelance
#  Các cành không mang trái, cành già yếu, cành bị nhiễm bệnh nên được loại bỏ vì chúng góp phần vào sự phát triển của sâu bệnh hại, cản trở ánh sáng mặt trời tiếp cận cây trồng và tiêu thụ tài nguyên mà lẽ ra có thể dành cho sản xuất quả khỏe mạnh hơn. Bằng cách loại bỏ những cành này, khu vườn nhận được nhiều ánh nắng mặt trời hơn, tăng cường lưu thông không khí và thúc đẩy sức khỏe tổng thể của cây. Điều này cũng hỗ trợ duy trì môi trường lành mạnh cho toàn bộ hệ thống cây cối. </s>
#  Để chăm sóc đúng cách cây lan chi, hãy đảm bảo rằng nó nhận được ánh sáng mặt trời gián tiếp, chẳng hạn như dưới tán cây khác hoặc gần cửa sổ với rèm che. Giữ đất ẩm nhưng tránh tưới quá nhiều nước; nước mưa hoặc nước cất là lý tưởng nhất. Cây thích đất giàu chất hữu cơ, thoáng khí với độ pH từ 6-7,5. Cắt tỉa lá vàng hoặc hư hỏng để thúc đẩy sự phát triển khỏe mạnh hơn nữa. </s>
#  Dựa trên ngữ cảnh đã cho, loài thực vật thuộc chi Sầu riêng phổ biến nhất là Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á. </s>
# Cannot find document revelance
#  Tôi xin lỗi, nhưng tôi không thể tìm thấy bất kỳ đề cập nào về thủy tùng trong ngữ cảnh đã cho. Có lẽ bạn đang nghĩ đến một loại cây khác mà mình muốn xác định. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Tôi xin lỗi, tôi không thể tìm thấy bất kỳ thông tin cụ thể nào liên quan đến việc xác định tỉnh nào ở Việt Nam có diện tích cây cà phê lớn nhất dựa trên ngữ cảnh đã cho. </s>
# ________________________________________________________________________________
# Top k: 5  ----- Threshold: 0.65
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
#  Cây nha đam có nhiều lợi ích cho sức khỏe do tính chất kháng khuẩn và chữa bệnh tự nhiên của nó. Nó thường được sử dụng trong các sản phẩm chăm sóc da vì đặc tính dưỡng ẩm và phục hồi của nó. Nha đam cũng đã được chứng minh là hữu ích trong việc thúc đẩy tiêu hóa lành mạnh, hỗ trợ hệ thống miễn dịch và cải thiện chức năng gan. Uống nước ép lô hội tươi có thể tăng cường mức năng lượng và thậm chí giúp kiểm soát cân nặng. Tuy nhiên, quan trọng nhất là tham khảo ý kiến bác sĩ trước khi bắt đầu bất kỳ chế độ ăn uống mới hoặc thay đổi lối sống nào. </s>
#  Để chăm sóc đúng cách cho cây lan Vanda, hãy đảm bảo rằng chúng nhận được nhiệt độ từ 25 - 30 độ C, độ ẩm khoảng 70-80%. Tưới nước đều đặn, đặc biệt là trong thời kỳ khô hạn. Vì đây là giống ưa sáng nên chúng cần ánh sáng mạnh mẽ để nở hoa. Ngoài ra, duy trì hệ thống thoát nước thích hợp và bón phân cân đối mỗi tuần một lần cũng góp phần tạo môi trường lý tưởng cho cây phát triển khỏe mạnh. </s>
#  Để phòng trừ côn trùng và nấm bệnh trên cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây, ảnh hưởng trực tiếp đến chất lượng và khả năng đậu trái. Do đó, nên tập trung cẩn thận vào các biện pháp này để đảm bảo kết quả tốt nhất cho vườn cây ăn quả của bạn. </s>
#  Để trồng và chăm sóc cây chu đinh lan, hãy làm theo hướng dẫn sau đây :
#
# 1. Chọn loại đất thích hợp: Chu đinh lan ưa đất tơi xốp, thoát nước tốt và duy trì độ ẩm khoảng 60-70 %. Đảm bảo rằng đất có hệ thống thoát nước đầy đủ để ngăn ngừa rễ cây bị ngập lụt.
#
# 2. Nhân giống: Có thể nhân giống cây chu đinh lan bằng phương pháp tách bụi. Sau khi đã trồng cây mẹ được một thời gian, bạn có thể bắt đầu tách cây con. Sử dụng một tay để giữ bụi lan, đồng thời sử dụng hỗn hợp đất trồng trong chậu. Phủ lên trên 1/3 củ trước khi đặt nó trở lại vị trí cũ. Vì củ lan rất dễ bị thối nên tránh chôn sâu hơn nữa. Việc tách cành không yêu cầu nhiều củ như đối với các loài lan khác.
#
# 3. Tưới nước: Mặc dù chu đinh lan có thể tồn tại mà không cần tưới nhiều nước, nhưng việc tưới thường xuyên vẫn khuyến khích cây ra hoa nhiều và liên tục. Hãy cố gắng tưới mỗi tuần hai lần.
#
# 4. Ánh nắng mặt trời: Cây sinh trưởng tốt trong điều kiện ánh sáng mặt trời toàn phần, vì vậy hãy đảm bảo cây nhận ít nhất tám giờ chiếu sáng trực tiếp mỗi ngày.
#
# 5. Nhiệt độ: Chu đinh lan có thể chịu được cả nhiệt độ cao lẫn lạnh, miễn sao đừng quá khắc nghiệt. Duy trì mức nhiệt độ vừa phải quanh năm.
#
# Bằng cách làm theo những nguyên tắc đơn giản này, bạn có thể nuôi dưỡng thành công cây chu đinh lan và tận hưởng vẻ đẹp rực rỡ cùng hương thơm ngọt ngào của nó! </s>
#  Để chăm sóc hoa lan Cattleya, hãy chú ý đến nhu cầu ánh sáng, tưới nước và bón phân của nó. Đảm bảo rằng môi trường sống của cây nhận đủ lượng ánh nắng trực tiếp, vì đây là yếu tố quan trọng đối với sự phát triển và nở hoa của cây. Tưới nước cho cây đều đặn, tránh tưới quá nhiều nước dẫn đến thối rễ. Bón phân cân đối mỗi tháng một lần trong mùa sinh trưởng (mùa xuân và hè) để thúc đẩy tăng trưởng và nở hoa tối ưu. Theo dõi chặt chẽ cây để phát hiện sớm các vấn đề tiềm ẩn như côn trùng xâm nhập hoặc nhiễm nấm, đồng thời xử lý kịp thời để duy trì sức khỏe tổng quát của cây. </s>
#  Để điều trị sâu ăn lá hoặc bám vào cây hoa Lan Cattleya, hãy xem xét việc phun thuốc diệt sâu bệnh lên cây hoặc loại bỏ chúng nếu có thể. Ngoài ra, kiểm tra và cắt bỏ bất kỳ phần nào của cây đã chết hoặc bị hư hại do sâu bệnh gây ra. Điều quan trọng cũng là duy trì môi trường sạch sẽ và vệ sinh để ngăn chặn vấn đề sâu bệnh tái diễn. Tham khảo ý kiến chuyên gia làm vườn địa phương hoặc nhà cung cấp sản phẩm chăm sóc cây trồng để nhận thêm hướng dẫn cụ thể dựa trên nhu cầu cá nhân của cây. </s>
#  Truy xuất nguồn gốc sản phẩm rất cần thiết để đảm bảo an toàn vệ sinh thực phẩm và uy tín thương mại. Bằng cách hỗ trợ truy xuất nguồn gốc sản phẩm, 2Nông giúp nông dân theo dõi lịch sử trồng trọt, kiểm soát chất lượng đầu vào và đầu ra, đồng thời xác nhận nguồn gốc xuất xứ của sản phẩm. Điều này đặc biệt hữu ích khi nông sản được xuất khẩu vì nó chứng tỏ độ tin cậy và trách nhiệm của doanh nghiệp. Ngoài ra, việc truy xuất nguồn gốc cũng giúp ngăn chặn gian lận thương mại và duy trì niềm tin giữa người tiêu dùng và nhà sản xuất. </s>
#  Để bổ sung chất hữu cơ cho đất sau thu hoạch đối với vườn cây ăn trái, bạn có thể áp dụng các phương pháp sau đây:
# 1. Bổ sung dinh dưỡng và chất hữu cơ cho đất: Sử dụng phân chuồng ủ hoai mục, phân xanh, phân trùn quế, đạm cá, phân NPK hữu cơ,... để nâng cao hàm lượng dinh dưỡng và chất hữu cơ trong đất.
# 2. Che phủ bằng cách để cỏ hoặc sử dụng các nguyên liệu hữu cơ: Dùng cỏ hoặc các loại nguyên liệu khác như rơm rạ, cành lá khô, tàn dư hoa màu, bèo lục bình, thân lá chuối, trấu,... để che phủ bề mặt đất. Các nguyên liệu này sẽ bị vi sinh vật đất phân hủy thành mùn, góp phần cải thiện cấu trúc đất và khả năng giữ ẩm.
# 3. Bổ sung vi sinh vật vào đất để cải tạo đất sau thu hoạch: Áp dụng biện pháp sử dụng phân bón vi sinh nhằm thúc đẩy sự phát triển của quần xã vi sinh vật có ích trong đất, từ đó hỗ trợ chuyển hóa chất hữu cơ thành dạng mà cây trồng dễ tiếp cận hơn. Điều này cũng giúp cân bằng hệ sinh thái vi sinh vật trong đất. </s>
#  Thời điểm tốt nhất để bón đạm cho lúa là trước lúc cấy và lúc cây lúa bắt đầu làm đòng. Không nên bón đạm ngay sau khi cấy và tránh bón đạm khi trời sắp mưa hoặc nắng nóng gay gắt. Bón đạm vào buổi sáng hoặc chiều tối là lý tưởng hơn cả. </s>
#  Để khắc phục nứt trái trên cây trồng, hãy xem xét các bước sau đây:
#
# 1. Kiểm soát lượng nước: Đảm bảo rằng cây nhận đủ nước mà không bị ngập lụt. Điều chỉnh lịch tưới dựa trên điều kiện khí hậu địa phương và yêu cầu cụ thể của loại cây trồng. Tránh tưới quá nhiều nước vì nó có thể góp phần vào sự phát triển của vi khuẩn và nấm.
#
# 2. Bón cân đối: Cung cấp dinh dưỡng đầy đủ cho cây trồng, đặc biệt chú ý đến hàm lượng kali và canxi. Những chất dinh dưỡng này đóng vai trò quan trọng trong cấu trúc tế bào và sức khỏe tổng quát của trái cây. Sử dụng phân bón cân đối theo khuyến cáo của nhà sản xuất.
#
# 3. Loại bỏ hoa đực sớm: Hoa đực tạo ra phấn hoa, nếu không thụ tinh thì chúng trở thành hạt giống ăn vào trái cây. Việc loại bỏ hoa đực sớm giảm thiểu nguy cơ hình thành hạt giống bên trong trái cây, có thể gây áp lực lên da và dẫn đến nứt nẻ.
#
# 4. Bảo vệ khỏi sâu hại: Sâu hại như ruồi đục quả có thể xâm nhập vào trái cây qua vết thương nhỏ, phá vỡ lớp vỏ và góp phần gây nứt nẻ. Thực hành kiểm soát dịch hại thích hợp như sử dụng bẫy dính màu vàng hoặc màng bọc trái cây để ngăn chặn côn trùng tiếp cận trái cây.
#
# 5. Chọn giống kháng: Một số loài cây đã được lai tạo để có khả năng chống lại vấn đề nứt trái tốt hơn. Hãy tìm kiếm các giống này khi chọn mua cây mới.
#
# 6. Theo dõi chặt chẽ: Thường xuyên kiểm tra vườn cây để phát hiện dấu hiệu căng thẳng hoặc tổn thương tiềm ẩn. Can thiệp kịp thời có thể giúp ngăn ngừa nứt trái trước khi xảy ra.
#
# Bằng cách thực hiện các biện pháp phòng ngừa này, bạn có thể giảm đáng kể tỷ lệ nứt trái trên cây trồng và đảm bảo thu hoạch tối ưu. </s>
# Cannot find document revelance
#  Để đảm bảo cà phê ra hoa đồng loạt, quan trọng là xác định thời điểm tưới nước thích hợp dựa trên điều kiện thời tiết địa phương, loại đất và sức khỏe tổng thể của cây trồng. Khi nhận thấy sự hình thành nụ hoa đầy đủ dưới dạng mỏ sẻ tại đốt ngoài cùng của các cành, hãy bắt đầu quá trình tưới nước. Tưới nước đúng cách và đều đặn trong đợt đầu tiên rất quan trọng đối với kết quả mong muốn này. </s>
#  Để phòng trị sâu vẽ bùa trên cây cam, sử dụng phương pháp phun loại thuốc lưu dẫn hoặc quét thuốc lưu dẫn ở giai đoạn mới nhú đọt non (bằng hạt gạo). </s>
#  Để phòng trừ bệnh khô cành khô quả ở cây cà phê, nên áp dụng tổng hợp các biện pháp như trồng cây che bóng, cây ăn quả với mật độ hợp lý, bón phân đầy đủ, kiểm tra vườn cây thường xuyên, cắt bỏ quả, cành bị gây hại nặng, đồng thời sử dụng một số loại thuốc hóa học khi cần thiết. </s>
#  Đối với cây hồ tiêu trong mô hình trồng hồ tiêu xen cà phê, lượng nước tưới khuyến nghị là khoảng 100 - 120 lít nước cho mỗi gốc/lần, hoặc có thể tưới tiết kiệm với khoảng 80 - 100 lít nước cho mỗi gốc/lần. Tưới 4 lần, mỗi chu kỳ tưới cách nhau 25 - 30 ngày. </s>
#  Để chăm sóc cây sau khi thu hoạch sầu riêng, bà con cần thực hiện vệ sinh gốc cây, tỉa cành, cắt tỉa cành và bón phân. Những bước này rất quan trọng để khôi phục sức khỏe của cây và chuẩn bị nó cho mùa vụ tiếp theo. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê là trước khi tiến hành bón phân và trước khi mùa mưa bắt đầu. Điều này đảm bảo rằng cây nhận đủ ánh sáng mặt trời và dinh dưỡng để phát triển khỏe mạnh và sản xuất hạt cà phê chất lượng cao hơn. </s>
#  <answer>Sản lượng lúa thu hoạch năm 2022 của Việt Nam ước đạt 42,66 triệu tấn.</answer> </s>
# Cannot find document revelance
#  Các cành không mang trái, cành già yếu, cành bị nhiễm bệnh nên được loại bỏ vì chúng góp phần vào sự phát triển của sâu bệnh hại, cản trở ánh sáng mặt trời tiếp cận cây trồng và tiêu thụ tài nguyên mà lẽ ra có thể dành cho sản xuất quả khỏe mạnh hơn. Bằng cách loại bỏ những cành này, khu vườn nhận được nhiều ánh nắng mặt trời hơn, tăng cường lưu thông không khí và thúc đẩy sức khỏe tổng thể của cây. Điều này cũng hỗ trợ duy trì môi trường lành mạnh cho toàn bộ hệ thống cây cối. </s>
#  Để chăm sóc đúng cách cây lan chi, hãy đảm bảo rằng nó nhận được ánh sáng mặt trời gián tiếp, chẳng hạn như dưới tán cây khác hoặc gần cửa sổ với rèm che. Giữ đất ẩm nhưng tránh tưới quá nhiều nước; nước mưa hoặc nước cất là lý tưởng nhất. Cây thích đất giàu chất hữu cơ, thoáng khí với độ pH từ 6-7,5. Cắt tỉa lá vàng hoặc hư hỏng để thúc đẩy sự phát triển khỏe mạnh hơn nữa. </s>
#  Dựa trên ngữ cảnh đã cho, loài thực vật thuộc chi Sầu riêng phổ biến nhất là Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Tôi xin lỗi, tôi không thể tìm thấy bất kỳ thông tin cụ thể nào liên quan đến việc xác định tỉnh nào ở Việt Nam có diện tích cây cà phê lớn nhất dựa trên ngữ cảnh đã cho. </s>
# ________________________________________________________________________________
# Top k: 5  ----- Threshold: 0.7
# Cannot find document revelance
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
#  Để chăm sóc đúng cách cho cây lan Vanda, hãy đảm bảo rằng nó nhận đủ lượng ánh sáng (ít nhất sáu tiếng mỗi ngày), duy trì nhiệt độ từ 25 - 30C và độ ẩm khoảng 70-80%. Tưới nước thường xuyên vào mùa hè nhưng giảm tần suất này xuống hai đến ba lần mỗi tuần trong thời kỳ nghỉ đông. Ngoài ra, bón phân cân đối hàng tháng trong suốt cả năm trừ giai đoạn nghỉ ngơi. </s>
#  Để phòng trừ côn trùng và nấm bệnh trên cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây, ảnh hưởng trực tiếp đến chất lượng và khả năng đậu trái. Do đó, nên tập trung cẩn thận vào các biện pháp này để đảm bảo kết quả tốt nhất cho vườn cây ăn quả của bạn. </s>
#  Để trồng và chăm sóc cây chu đinh lan, hãy làm theo hướng dẫn sau đây :
#
# 1. Chọn loại đất thích hợp: Chu đinh lan ưa đất tơi xốp, thoát nước tốt và duy trì độ ẩm khoảng 60-70 %. Đảm bảo rằng đất có hệ thống thoát nước đầy đủ để ngăn ngừa rễ cây bị ngập lụt.
#
# 2. Nhân giống: Có thể nhân giống cây chu đinh lan bằng phương pháp tách bụi. Sau khi đã trồng cây mẹ được một thời gian, bạn có thể bắt đầu tách cây con. Sử dụng một tay để giữ bụi lan, đồng thời sử dụng hỗn hợp đất trồng trong chậu. Phủ lên trên 1/3 củ trước khi đặt nó trở lại vị trí cũ. Vì củ lan rất dễ bị thối nên tránh chôn sâu hơn nữa. Việc tách cành không yêu cầu nhiều củ như đối với các loài lan khác.
#
# 3. Tưới nước: Mặc dù chu đinh lan có thể tồn tại mà không cần tưới nhiều nước, nhưng việc tưới thường xuyên vẫn khuyến khích cây ra hoa nhiều và liên tục. Hãy cố gắng tưới mỗi tuần hai lần.
#
# 4. Ánh nắng mặt trời: Cây sinh trưởng tốt trong điều kiện ánh sáng mặt trời toàn phần, vì vậy hãy đảm bảo cây nhận ít nhất tám giờ chiếu sáng trực tiếp mỗi ngày.
#
# 5. Nhiệt độ: Chu đinh lan có thể chịu được cả nhiệt độ cao lẫn lạnh, miễn sao đừng quá khắc nghiệt. Duy trì mức nhiệt độ vừa phải quanh năm.
#
# Bằng cách làm theo những nguyên tắc đơn giản này, bạn có thể nuôi dưỡng thành công cây chu đinh lan và tận hưởng vẻ đẹp rực rỡ cùng hương thơm ngọt ngào của nó! </s>
#  Để chăm sóc hoa lan Cattleya, hãy chú ý đến việc tưới nước và ánh sáng. Tưới nước cho cây mỗi tuần một lần, trừ mùa đông. Đảm bảo rằng đất khô hoàn toàn trước khi tưới nước trở lại. Cung cấp đủ ánh nắng trực tiếp hàng ngày, lý tưởng nhất là sáu tiếng đồng hồ. Tránh để cây dưới ánh nắng quá gay gắt vì nó có thể gây cháy lá. Bón phân cân đối với tỷ lệ 10-10-10 hai tháng một lần trong suốt cả năm. Giữ môi trường ấm áp và ổn định quanh năm, duy trì nhiệt độ từ 65°F (18°C) đến 75°F (24°C). </s>
#  Để điều trị sâu ăn lá hoặc bám vào cây hoa Lan Cattleya, hãy xem xét việc phun thuốc diệt sâu bệnh lên cây hoặc loại bỏ chúng nếu có thể. Ngoài ra, kiểm tra và cắt bỏ bất kỳ phần nào của cây đã chết hoặc bị hư hại do sâu bệnh gây ra. Điều quan trọng cũng là duy trì môi trường sạch sẽ và vệ sinh để ngăn chặn vấn đề sâu bệnh tái diễn. Tham khảo ý kiến chuyên gia làm vườn địa phương hoặc nhà cung cấp sản phẩm chăm sóc cây trồng để nhận thêm hướng dẫn cụ thể dựa trên nhu cầu cá nhân của cây. </s>
#  Truy xuất nguồn gốc sản phẩm rất cần thiết để đảm bảo độ tin cậy và an toàn của hàng hóa trước khi chúng đến tay khách hàng cuối cùng. Bằng cách sử dụng 2Nông, việc theo dõi lịch sử trồng trọt, thu hoạch và vận chuyển trở nên đơn giản hơn. Điều này làm cho nó dễ dàng xác định bất kỳ vấn đề tiềm ẩn nào liên quan đến sản phẩm, chẳng hạn như ô nhiễm hoặc sai sót trong chuỗi cung ứng. Ngoài ra, truy xuất nguồn gốc cải thiện niềm tin giữa người tiêu dùng và nhà sản xuất, dẫn đến mối quan hệ tốt đẹp hơn và doanh số bán hàng lớn hơn. Do vậy, 2Nông hỗ trợ truy xuất nguồn gốc sản phẩm nhằm tạo điều kiện thuận lợi cho việc xuất khẩu nông sản với nguồn gốc xuất xứ rõ ràng, thúc đẩy thương mại quốc tế và mở rộng thị trường cho nông dân Việt Nam. </s>
#  Để bổ sung chất hữu cơ cho đất sau thu hoạch đối với vườn cây ăn trái, bạn có thể áp dụng các phương pháp sau đây:
# 1. Bổ sung dinh dưỡng và chất hữu cơ cho đất: Sử dụng phân chuồng ủ hoai mục, phân xanh, phân trùn quế, đạm cá, phân NPK hữu cơ,... để nâng cao hàm lượng dinh dưỡng và chất hữu cơ trong đất.
# 2. Che phủ bằng cách để cỏ hoặc sử dụng các nguyên liệu hữu cơ: Dùng cỏ hoặc các loại nguyên liệu khác như rơm rạ, cành lá khô, tàn dư hoa màu, bèo lục bình, thân lá chuối, trấu,... để che phủ bề mặt đất. Các nguyên liệu này sẽ bị vi sinh vật đất phân hủy thành mùn, góp phần cải thiện cấu trúc đất và khả năng giữ ẩm.
# 3. Bổ sung vi sinh vật vào đất để cải tạo đất sau thu hoạch: Áp dụng biện pháp sử dụng phân bón vi sinh nhằm thúc đẩy sự phát triển của quần xã vi sinh vật có ích trong đất, từ đó hỗ trợ chuyển hóa chất hữu cơ thành dạng mà cây trồng dễ tiếp cận hơn. Điều này cũng giúp cân bằng hệ sinh thái vi sinh vật trong đất. </s>
#  Thời điểm tốt nhất để bón đạm cho lúa là trước lúc cấy và lúc cây lúa bắt đầu làm đòng. Không nên bón đạm ngay sau khi cấy và tránh bón đạm khi trời sắp mưa hoặc nắng nóng gay gắt. Bón đạm vào buổi sáng hoặc chiều tối là lý tưởng hơn cả. </s>
#  Tôi xin lỗi, nhưng thông tin được cung cấp không đề cập đến vấn đề cụ thể về nứt trái trên cây trồng. </s>
# Cannot find document revelance
#  Để đảm bảo cà phê ra hoa đồng loạt, quan trọng là xác định thời điểm tưới nước thích hợp dựa trên điều kiện thời tiết địa phương, loại đất và sức khỏe tổng thể của cây trồng. Khi nhận thấy sự hình thành nụ hoa đầy đủ dưới dạng mỏ sẻ tại đốt ngoài cùng của các cành, hãy bắt đầu quá trình tưới nước. Tưới nước đúng cách và đều đặn trong đợt đầu tiên rất quan trọng đối với kết quả mong muốn này. </s>
#  Để phòng trị sâu vẽ bùa trên cây cam, sử dụng phương pháp phun loại thuốc lưu dẫn hoặc quét thuốc lưu dẫn ở giai đoạn mới nhú đọt non (bằng hạt gạo). </s>
#  Để phòng trừ bệnh khô cành khô quả ở cây cà phê, nên áp dụng tổng hợp các biện pháp như trồng cây che bóng, cây ăn quả với mật độ hợp lý, bón phân đầy đủ, kiểm tra vườn cây thường xuyên, cắt bỏ quả, cành bị gây hại nặng, đồng thời sử dụng một số loại thuốc hóa học khi cần thiết. </s>
#  Đối với cây hồ tiêu trong mô hình trồng hồ tiêu xen cà phê, lượng nước tưới khuyến nghị là khoảng 100 - 120 lít nước cho mỗi gốc/lần, hoặc có thể tưới tiết kiệm với khoảng 80 - 100 lít nước cho mỗi gốc/lần. Tưới 4 lần, mỗi chu kỳ tưới cách nhau 25 - 30 ngày. </s>
#  Để chăm sóc cây sau khi thu hoạch sầu riêng, bà con cần thực hiện vệ sinh gốc cây, tỉa cành và bón phân cân đối. Điều này đảm bảo rằng cây khỏe mạnh và sẵn sàng cho mùa vụ tiếp theo. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê là trước khi tiến hành bón phân và trước khi mùa mưa bắt đầu. Điều này đảm bảo rằng cây nhận đủ ánh sáng mặt trời và dinh dưỡng để phát triển khỏe mạnh và sản xuất hạt cà phê chất lượng cao hơn. </s>
#  <answer>Sản lượng lúa thu hoạch năm 2022 của Việt Nam ước đạt 42,66 triệu tấn.</answer> </s>
# Cannot find document revelance
# Cannot find document revelance
#  Để chăm sóc đúng cách cây lan chi, hãy đảm bảo rằng nó nhận được ánh sáng mặt trời gián tiếp, chẳng hạn như dưới tán cây khác hoặc gần cửa sổ với rèm che. Giữ đất ẩm nhưng tránh tưới quá nhiều nước; nước mưa hoặc nước cất là lý tưởng nhất. Cây thích đất giàu chất hữu cơ, thoáng khí với độ pH từ 6-7,5. Cắt tỉa lá vàng hoặc hư hỏng để thúc đẩy sự phát triển khỏe mạnh hơn nữa. </s>
#  Dựa trên ngữ cảnh đã cho, loài thực vật thuộc chi Sầu riêng phổ biến nhất là Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# ________________________________________________________________________________
# Top k: 5  ----- Threshold: 0.75
# Cannot find document revelance
# Cannot find document revelance
#  Để
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# phòng trừ côn trùng và nấm bệnh trên cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây, ảnh hưởng trực tiếp đến chất lượng và khả năng đậu trái. Do đó, nên tập trung cẩn thận vào các biện pháp này để đảm bảo kết quả tốt nhất cho vườn cây ăn quả của bạn. </s>
#  Để trồng và chăm sóc cây lan chu đinh, hãy làm theo hướng dẫn dưới đây:
# 1. Chọn loại đất thích hợp: Cây lan chu đinh phát triển mạnh ở nhiều loại đất khác nhau, nhưng lý tưởng nhất là đất thịt, đất mùn, đất cát pha. Đảm bảo rằng đất tơi xốp, thoát nước tốt và giữ ẩm tốt.
# 2. Trồng cây đúng cách: Khi trồng cây lan chu đinh, đào hố sâu hơn rễ khoảng 5 cm. Đặt cây vào lỗ sao cho cổ rễ ngang với mặt đất. Lấp đất lên gốc cây và nén nhẹ xuống. Tưới nước ngay lập tức để đảm bảo độ ẩm cho cây.
# 3. Chăm sóc thường xuyên: Duy trì độ ẩm đều đặn cho cây lan chu đinh bằng cách tưới nước thường xuyên. Tuy nhiên, tránh tưới quá nhiều vì nó có thể gây thối rễ. Bón phân cân đối mỗi tháng một lần trong mùa sinh trưởng (xuân đến thu) để thúc đẩy tăng trưởng khỏe mạnh. Cắt tỉa bất kỳ lá vàng hoặc hư hỏng nào để duy trì sức hấp dẫn thẩm mỹ của cây.
# 4. Nhân giống: Có thể nhân giống cây lan chu đinh bằng phương pháp tách bụi. Sau khi trồng cây mẹ được một thời gian, bạn có thể tiến hành tách cây con. Sử dụng một tay để giữ bụi lan, tay kia cẩn thận lấy cây con ra khỏi thân chính. Trồng chúng ở nơi mới và tiếp tục chăm sóc chúng.
# Bằng cách làm theo những bước đơn giản này, bạn có thể dễ dàng trồng và chăm sóc cây lan chu đinh, mang lại vẻ đẹp cho khu vực ngoài trời của mình đồng thời tận hưởng lợi ích từ việc sử dụng y học truyền thống của nó. </s>
#  Để chăm sóc hoa lan Cattleya, hãy đảm bảo rằng nó nhận đủ ánh sáng mặt trời trực tiếp nhưng tránh ánh nắng gay gắt vào buổi trưa. Duy trì độ ẩm cao từ 60% trở lên và tưới nước thường xuyên tùy thuộc vào khí hậu nơi trồng. Sử dụng hỗn hợp giá thể thoát nước tốt với xơ dừa, than củi, đá bọt, gốc cây mục, rêu sphagnum moss (mùn cưa) hoặc vỏ cây linh sam. Bón phân cân đối mỗi tháng một lần trong mùa sinh trưởng và giảm lượng bón phân xuống hai tuần một lần trong thời kỳ nghỉ đông. Theo dõi côn trùng gây hại tiềm ẩn và bệnh tật, đồng thời duy trì môi trường sạch sẽ và vệ sinh. </s>
# Cannot find document revelance
# Cannot find document revelance
#  Để bổ sung chất hữu cơ cho đất sau thu hoạch đối với vườn cây ăn trái, bạn có thể áp dụng các phương pháp sau đây:
# 1. Bổ sung dinh dưỡng và chất hữu cơ cho đất: Sử dụng phân chuồng ủ hoai mục, phân xanh, phân trùn quế, đạm cá, phân NPK hữu cơ,... để nâng cao hàm lượng dinh dưỡng và chất hữu cơ trong đất.
# 2. Che phủ bằng cách để cỏ hoặc sử dụng các nguyên liệu hữu cơ: Dùng cỏ hoặc các loại nguyên liệu khác như rơm rạ, cành lá khô, tàn dư hoa màu, bèo lục bình, thân lá chuối, trấu,... để che phủ bề mặt đất. Các nguyên liệu này sẽ bị vi sinh vật đất phân hủy thành mùn, góp phần cải thiện cấu trúc đất và khả năng giữ ẩm.
# 3. Bổ sung vi sinh vật vào đất để cải tạo đất sau thu hoạch: Áp dụng biện pháp sử dụng phân bón vi sinh nhằm thúc đẩy sự phát triển của quần xã vi sinh vật có ích trong đất, từ đó hỗ trợ chuyển hóa chất hữu cơ thành dạng mà cây trồng dễ tiếp cận hơn. Điều này cũng giúp cân bằng hệ sinh thái vi sinh vật trong đất. </s>
#  Thời điểm tốt nhất để bón đạm cho lúa là trước lúc cấy và lúc cây lúa bắt đầu làm đòng. Không nên bón đạm ngay sau khi cấy và tránh bón đạm khi trời sắp mưa hoặc nắng nóng gay gắt. Bón đạm vào buổi sáng hoặc chiều tối là lý tưởng hơn cả. </s>
# Cannot find document revelance
# Cannot find document revelance
#  Để đảm bảo cà phê ra hoa đồng loạt, quan trọng là xác định thời điểm tưới nước thích hợp dựa trên điều kiện thời tiết địa phương, loại đất và sức khỏe tổng thể của cây trồng. Khi nhận thấy sự hình thành nụ hoa đầy đủ dưới dạng mỏ sẻ tại đốt ngoài cùng của các cành, hãy bắt đầu quá trình tưới nước. Tưới nước đúng cách và đều đặn trong đợt đầu tiên rất quan trọng đối với kết quả mong muốn này. </s>
# Cannot find document revelance
#  Để phòng trừ bệnh khô cành khô quả ở cây cà phê, nên áp dụng tổng hợp các biện pháp như trồng cây che bóng, cây ăn quả với mật độ hợp lý, bón phân đầy đủ, kiểm tra vườn cây thường xuyên, cắt bỏ quả, cành bị gây hại nặng, đồng thời sử dụng một số loại thuốc hóa học khi cần thiết. </s>
# Cannot find document revelance
#  Để chăm sóc cây sau khi thu hoạch sầu riêng, bà con cần thực hiện vệ sinh gốc cây, tỉa cành và bón phân cân đối. Điều này đảm bảo rằng cây khỏe mạnh và sẵn sàng cho mùa vụ tiếp theo. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Tôi xin lỗi, nhưng thông tin được cung cấp không đề cập cụ thể đến thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê. Thông tin tập trung chủ yếu vào quá trình tưới nước và chăm sóc cây trồng liên quan đến sự phát triển của chúng. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Để chăm sóc đúng cây lan chu đinh, hãy đảm bảo rằng nó nhận đủ ánh sáng mặt trời trực tiếp (ít nhất sáu đến tám tiếng mỗi ngày) và tưới nước thường xuyên nhưng tránh ngập úng. Bón phân cân đối hàng tháng vào mùa sinh trưởng và cắt tỉa bớt lá chết hoặc hư hỏng. Ngoài ra, duy trì độ pH từ 5,5 đến 6,5 và kiểm soát sâu bệnh hại nếu cần thiết. </s>
#  Dựa trên ngữ cảnh đã cho, loài thực vật thuộc chi Sầu riêng phổ biến nhất là Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# ________________________________________________________________________________
# Top k: 5  ----- Threshold: 0.8
# Cannot find document revelance
# Cannot find document revelance
#  Để
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# phòng trừ côn trùng và nấm bệnh trên cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây, ảnh hưởng trực tiếp đến chất lượng và khả năng đậu trái. Do đó, nên tập trung cẩn thận vào các biện pháp này để đảm bảo kết quả tốt nhất cho vườn cây ăn quả của bạn. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Để chăm sóc cây sau khi thu hoạch sầu riêng, bà con cần thực hiện vệ sinh gốc cây, tỉa cành và bón phân cân đối. Điều này đảm bảo rằng cây khỏe mạnh và sẵn sàng cho mùa vụ tiếp theo. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Dựa trên ngữ cảnh đã cho, loài thực vật thuộc chi Sầu riêng phổ biến nhất là Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# ________________________________________________________________________________

# %%
folder_save_evaluate = "./evaluate/"
prompt_name = "prompt_template_2_cosine_evaluate"    
prompt_template_use = prompt_template_2
folder_save_result_prompt = folder_save_evaluate + prompt_name + "/"
os.makedirs(folder_save_result_prompt, exist_ok=True)
with open(folder_save_result_prompt + "prompt_template.txt", 'w') as f:
    f.write(prompt_template_use)
tempearature = 0
top_p = 0
score_evaluate = 'cosine_score'
# topk = 5
for topk in [5]:
    for thresh_combined in [0.5, 0.6, 0.65, 0.7, 0.75, 0.8]:
        print(f"Top k: {topk}  ----- Threshold: {thresh_combined}")
        test_df = test_evaluate.copy()
        test_df['vietmistal_result'] = test_df['question'].apply(lambda x: rag(x, topk=topk, score_evaluate=score_evaluate, threshold_score=thresh_combined, top_p=top_p,prompt_template=prompt_template_use))
        test_df= test_df.join(pd.DataFrame(test_df['vietmistal_result'].values.tolist()))
        test_df.to_excel(folder_save_result_prompt + f"vietmistal_result_threshole_{thresh_combined}_tempearature_{tempearature}_top{topk}.xlsx", index=False)
        print("________"*10)
# Out:
# Top k: 5  ----- Threshold: 0.5
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
#  Công dụng của cây nha đam bao gồm sát khuẩn, chống lão hóa, giảm sưng, viêm, bảo vệ đường ruột, dạ dày, cải thiện chất lượng giấc ngủ và hỗ trợ não bộ. </s>
#  Để chăm sóc đúng cách cây lan Vanda, hãy đảm bảo rằng nó nhận được nhiệt độ từ 25 - 30 độ C, duy trì độ ẩm khoảng 70-80%. Tưới nước đều đặn, đặc biệt là trong thời kỳ khô hạn hoặc mùa hè. Cây cũng thích ánh sáng mạnh, vì vậy đặt chúng dưới ánh mặt trời trực tiếp hoặc sử dụng bóng đèn chuyên dùng cho cây cảnh. Ngoài ra, bón phân cân đối mỗi tuần một lần trong suốt cả năm để thúc đẩy sự phát triển khỏe mạnh. </s>
#  Để phòng trừ côn trùng và nấm bệnh cho cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây. </s>
#  Để trồng và chăm sóc cây chu đinh lan, hãy làm theo những bước sau:
#
# 1. Chọn loại đất phù hợp: Sử dụng đất thịt, đất mùn hoặc đất cát pha với tính thấm nước cao và giữ ẩm tốt. Đảm bảo rằng đất tơi xốp và thoáng khí.
#
# 2. Nhân giống: Thực hiện phương pháp nhân giống bằng cách tách bụi. Chờ cho cây mẹ lớn lên rồi mới bắt đầu tách cây con.
#
# 3. Chuẩn bị chậu: Đặt chất trồng vào chậu sao cho nó bao phủ khoảng 1/3 củ. Vì rễ cây rất dễ bị thối nên tránh chôn sâu hơn nữa. Bạn không cần phải có nhiều củ như đối với các loài lan khác.
#
# 4. Tưới nước: Ngay sau khi trồng, tưới nước để duy trì độ ẩm cho cây. Chu đinh lan là loài có sức sống mạnh mẽ và ít yêu cầu chăm sóc, vì vậy việc tưới nước thường xuyên không cần thiết. Thông thường, tưới mỗi tuần hai lần là đủ.
#
# 5. Điều kiện ánh sáng: Đảm bảo cây nhận được ít nhất tám giờ ánh nắng trực tiếp mỗi ngày.
#
# 6. Độ ẩm: Duy trì mức độ ẩm từ 60% đến 70 %.
#
# 7. Nhiệt độ: Cây thích nghi tốt với cả điều kiện nóng và lạnh, miễn là chúng nằm trong phạm vi từ 10°C đến 35°C (50°F đến 95°F).
#
# Bằng cách tuân thủ những hướng dẫn này, bạn có thể giúp cây chu đinh lan của mình khỏe mạnh và ra nhiều hoa. </s>
#  Để chăm sóc hoa lan Cattleya, hãy chọn giá thể thoáng rễ, có khả năng thoát nước nhanh nhưng vẫn giữ ẩm tốt. Chọn những cây khỏe mạnh với tép to và màu xanh tốt. Tạo móc treo để hỗ trợ cây và đặt nó vào chậu, đảm bảo rằng chỉ có gốc tiếp xúc với giá thể. Tưới nước đều đặn và bón phân cân đối mỗi tháng một lần. Giữ môi trường ấm áp và sáng sủa, tránh ánh nắng trực tiếp và gió lùa. Cắt tỉa cành chết và thay chậu sau hai năm. </s>
#  Để điều trị sâu ăn lá hoặc bám vào cây hoa Lan Cattleya, hãy xem xét việc phun thuốc diệt sâu bệnh hoặc loại bỏ chúng khỏi cây. Ngoài ra, cũng nên cắt bỏ bất kỳ cành lá bị khô héo hoặc nhiễm bệnh. </s>
#   </s>
#  Để bổ sung chất hữu cơ cho đất sau thu hoạch đối với vườn cây ăn trái, hãy tuân theo những phương pháp sau đây :
# 1. Bổ sung dinh dưỡng và chất hữu cơ cho đất: Sử dụng phân chuồng ủ hoai mục, phân xanh, phân trùn quế, đạm cá, phân NPK hữu cơ,...
# 2. Che phủ bằng cách để cỏ hoặc dùng nguyên liệu hữu cơ: Cỏ hoặc các loại nguyên liệu khác như rơm rạ, cành lá khô, tàn dư hoa màu, bèo lục bình, thân lá chuối, trấu... sẽ rất tốt cho việc bổ sung thêm chất hữu cơ cho đất.
# 3. Bổ sung vi sinh vật vào đất để cải tạo đất sau thu hoạch: Sử dụng phân bón vi sinh để cân bằng hệ sinh thái vi sinh vật trong đất nhằm cải thiện sức khỏe tổng quát của đất. </s>
#  Thời điểm tốt nhất để bón đạm cho lúa là trước lúc cấy và lúc cây lúa bắt đầu làm đòng. Không nên bón đạm ngay sau khi cấy và tránh bón trong điều kiện thời tiết bất lợi như chuẩn bị mưa lớn hoặc nắng nóng gay gắt. Bón đạm hiệu quả hơn vào buổi sáng hoặc chiều tối. </s>
#  Để khắc phục nứt trái trên cây trồng, hãy đảm bảo rằng cây nhận đủ lượng nước cần thiết mà không phải đối mặt với sự dư thừa. Ngoài ra, kiểm soát sâu bệnh như vi khuẩn và nấm bằng cách sử dụng thuốc trừ sâu thích hợp. Cắt tỉa những cành mọc dày đặc để cải thiện lưu thông gió và giảm nguy cơ nhiễm trùng. Cuối cùng, áp dụng lớp phủ hữu cơ để giữ ẩm và ngăn chặn cỏ dại cạnh tranh chất dinh dưỡng. </s>
#  Để khắc phục mít xơ đen, hãy đảm bảo rằng bạn đã cung cấp đủ canxi bằng cách bón phân canxi hòa tan dạng chelate (Ca - Chelate), đồng thời sử dụng tấm nhựa để ngăn chặn sự tiếp xúc với nước mưa trong quá trình thụ phấn. Ngoài ra, duy trì độ pH từ 5.5 đến 7.0 và tránh trồng các loại cây khác như đu đủ hoặc chuối vì chúng cũng dễ mắc bệnh nấm. </s>
#  Để cà phê ra hoa đồng loạt, hãy đảm bảo rằng bạn tưới nước sau thời kỳ khô hạn khi nụ hoa đã hình thành hoàn toàn tại đốt cuối cùng trên mỗi nhánh. Tưới nước đúng cách trong đợt đầu tiên với lượng thích hợp phụ thuộc vào điều kiện môi trường cụ thể như kiểu khí hậu địa phương, chất lượng đất và sức khỏe tổng quát của cây trồng. Bằng cách tuân theo những hướng dẫn này, bạn có thể thúc đẩy sự nở rộ đều đặn và hiệu quả hơn từ vườn cà phê của bạn. </s>
#  Tôi không biết trả lời câu hỏi này. </s>
#  Để phòng trừ bệnh khô cành khô quả cho cây cà phê, cần áp dụng tổng hợp các biện pháp như trồng cây che bóng, cây ăn quả với mật độ hợp lý, bón phân đầy đủ, kiểm tra vườn cây thường xuyên và xử lý bằng thuốc hóa học khi cần thiết. </s>
#  Đối với cây hồ tiêu, lượng nước tưới khuyến nghị trong mô hình trồng hồ tiêu xen cà phê là từ 100-120 lít nước cho mỗi gốc/lần, hoặc có thể tưới tiết kiệm với khoảng 80-100 lít nước cho mỗi gốc/lần. Tưới 4 lần, mỗi chu kỳ tưới cách nhau 25-30 ngày. </s>
#  Sau khi thu hoạch sầu riêng, cần thực hiện vệ sinh gốc cây, tỉa cành và bón phân để chăm sóc cây. </s>
#  Tôi không biết trả lời câu hỏi này. </s>
#  Tên gọi tiếng Việt của loài dừa nước là dừa lá. </s>
#  Tên khoa học của cây đủng đỉnh là Caryota mitis. </s>
#  Thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê là trước khi tiến hành bón phân và trước khi mùa mưa bắt đầu. </s>
#  Dựa trên ngữ cảnh cho trước, sản lượng lúa thu hoạch năm 2022 của Việt Nam ước tính khoảng 42,66 triệu tấn. </s>
# Cannot find document revelance
#  Các cành không mang trái, cành già yếu, cành bị nhiễm bệnh nên được loại bỏ vì chúng cản trở ánh nắng mặt trời tiếp cận phần còn lại của cây, dẫn đến tăng trưởng kém hiệu quả hơn. Chúng cũng góp phần gây mất cân bằng dinh dưỡng do tiêu thụ tài nguyên mà lẽ ra sẽ dành cho những bộ phận khỏe mạnh khác của cây. Hơn nữa, chúng có thể thu hút sâu bệnh hại, ảnh hưởng xấu đến sức khỏe tổng thể của cây trồng. Bằng cách loại bỏ những cành như vậy, người ta giúp duy trì môi trường lành mạnh và hỗ trợ cho toàn bộ khu vườn. </s>
#  Để chăm sóc đúng cách cây lan chi, hãy đảm bảo rằng nó nhận được ánh sáng 1 phần, đất mùn với độ pH từ 6 - 7.5, và đất thoát nước tốt. Tưới nước đều đặn, tránh sử dụng nước bị nhiễm phèn. Cây thích nghi tốt với điều kiện ấm áp hơn, khoảng 20°C (68°F). Cắt tỉa lá vàng hoặc hư hỏng để thúc đẩy sự phát triển khỏe mạnh. Nếu muốn nhân giống cây lan chi, bạn có thể tách bụi cây con sau mỗi năm rưỡi đến hai năm. </s>
#  Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á, là loài thực vật thuộc chi Sầu riêng phổ biến nhất. </s>
# Cannot find document revelance
#  Tôi không biết trả lời câu hỏi này </s>
#  Tre Mạnh Tông được mô tả khoa học lần đầu bởi Backer vào năm 1927. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Tôi không biết trả lời câu hỏi này vì nó không liên quan đến ngữ cảnh cung cấp. </s>
#  Tôi không biết trả lời câu hỏi này. </s>
#  Không đủ thông tin để cung cấp câu trả lời. </s>
# ________________________________________________________________________________
# Top k: 5  ----- Threshold: 0.6
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Cây nha đam có nhiều lợi ích cho sức khỏe như sát khuẩn, chống lão hóa, giảm sưng, viêm, bảo vệ đường ruột, dạ dày, giúp cải thiện chất lượng giấc ngủ và hỗ trợ chức năng não bộ. </s>
#  Để chăm sóc đúng cách cây lan Vanda, hãy đảm bảo rằng nó nhận được nhiệt độ từ 25 - 30 độ C, duy trì độ ẩm khoảng 70-80%. Tưới nước đều đặn, đặc biệt là trong thời kỳ khô hạn hoặc mùa hè. Cây cũng thích ánh sáng mạnh, vì vậy đặt chúng dưới ánh mặt trời trực tiếp hoặc sử dụng bóng đèn chuyên dùng cho cây cảnh. Ngoài ra, bón phân cân đối mỗi tuần một lần trong suốt cả năm để thúc đẩy sự phát triển khỏe mạnh. </s>
#  Để phòng trừ côn trùng và nấm bệnh cho cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây. </s>
#  Để trồng và chăm sóc cây chu đinh lan, hãy làm theo những bước sau:
#
# 1. Chọn loại đất phù hợp: Sử dụng đất thịt, đất mùn hoặc đất cát pha với tính thấm nước cao và giữ ẩm tốt. Đảm bảo rằng đất tơi xốp và thoáng khí.
#
# 2. Nhân giống: Thực hiện phương pháp nhân giống bằng cách tách bụi. Chờ cho cây mẹ lớn lên rồi mới bắt đầu tách cây con.
#
# 3. Chuẩn bị chậu: Đặt chất trồng vào chậu sao cho nó bao phủ khoảng 1/3 củ. Vì rễ cây rất dễ bị thối nên tránh chôn sâu hơn nữa. Bạn không cần phải có nhiều củ như đối với các loài lan khác.
#
# 4. Tưới nước: Ngay sau khi trồng, tưới nước để duy trì độ ẩm cho cây. Chu đinh lan là loài có sức sống mạnh mẽ và ít yêu cầu chăm sóc, vì vậy việc tưới nước thường xuyên không cần thiết. Thông thường, tưới mỗi tuần hai lần là đủ.
#
# 5. Điều kiện ánh sáng: Đảm bảo cây nhận được ít nhất tám giờ ánh nắng trực tiếp mỗi ngày.
#
# 6. Độ ẩm: Duy trì mức độ ẩm từ 60% đến 70 %.
#
# 7. Nhiệt độ: Cây thích nghi tốt với cả điều kiện nóng và lạnh, miễn là chúng nằm trong phạm vi từ 10°C đến 35°C (50°F đến 95°F).
#
# Bằng cách tuân thủ những hướng dẫn này, bạn có thể giúp cây chu đinh lan của mình khỏe mạnh và ra nhiều hoa. </s>
#  Để chăm sóc hoa lan Cattleya, hãy chọn giá thể thoáng rễ, có khả năng thoát nước nhanh nhưng vẫn giữ ẩm tốt. Chọn những cây khỏe mạnh với tép to và màu xanh tốt. Tạo móc treo để hỗ trợ cây và đặt nó vào chậu, đảm bảo rằng chỉ có gốc tiếp xúc với giá thể. Tưới nước đều đặn và bón phân cân đối mỗi tháng một lần. Giữ môi trường ấm áp và sáng sủa, tránh ánh nắng trực tiếp và gió lùa. Cắt tỉa cành chết và thay chậu sau hai năm. </s>
#  Để điều trị sâu ăn lá hoặc bám vào cây hoa Lan Cattleya, hãy xem xét việc phun thuốc diệt sâu bệnh hoặc loại bỏ chúng khỏi cây. Ngoài ra, cũng nên cắt bỏ bất kỳ cành lá bị khô héo hoặc nhiễm bệnh. </s>
#   </s>
#  Để bổ sung chất hữu cơ cho đất sau thu hoạch đối với vườn cây ăn trái, hãy tuân theo những phương pháp sau đây :
# 1. Bổ sung dinh dưỡng và chất hữu cơ cho đất: Sử dụng phân chuồng ủ hoai mục, phân xanh, phân trùn quế, đạm cá, phân NPK hữu cơ,...
# 2. Che phủ bằng cách để cỏ hoặc dùng nguyên liệu hữu cơ: Cỏ hoặc các loại nguyên liệu khác như rơm rạ, cành lá khô, tàn dư hoa màu, bèo lục bình, thân lá chuối, trấu... sẽ rất tốt cho việc bổ sung thêm chất hữu cơ cho đất.
# 3. Bổ sung vi sinh vật vào đất để cải tạo đất sau thu hoạch: Sử dụng phân bón vi sinh để cân bằng hệ sinh thái vi sinh vật trong đất nhằm cải thiện sức khỏe tổng quát của đất. </s>
#  Thời điểm tốt nhất để bón đạm cho lúa là trước lúc cấy và lúc cây lúa bắt đầu làm đòng. Không nên bón đạm ngay sau khi cấy và tránh bón trong điều kiện thời tiết bất lợi như chuẩn bị mưa lớn hoặc nắng nóng gay gắt. Bón đạm hiệu quả hơn vào buổi sáng hoặc chiều tối. </s>
#  Để khắc phục nứt trái trên cây trồng, hãy đảm bảo rằng cây nhận đủ lượng nước cần thiết mà không phải đối mặt với sự dư thừa. Ngoài ra, kiểm soát sâu bệnh như vi khuẩn và nấm bằng cách sử dụng thuốc trừ sâu thích hợp. Cắt tỉa những cành mọc dày đặc để cải thiện lưu thông gió và giảm nguy cơ nhiễm trùng. Cuối cùng, áp dụng lớp phủ hữu cơ để giữ ẩm và ngăn chặn cỏ dại cạnh tranh chất dinh dưỡng. </s>
#  Để khắc phục mít xơ đen, hãy đảm bảo rằng bạn đã cung cấp đủ canxi bằng cách bón phân canxi hòa tan dạng chelate (Ca - Chelate), đồng thời sử dụng tấm nhựa để ngăn chặn sự tiếp xúc với nước mưa trong quá trình thụ phấn. Ngoài ra, duy trì độ pH từ 5.5 đến 7.0 và tránh trồng các loại cây khác như đu đủ hoặc chuối vì chúng cũng dễ mắc bệnh nấm. </s>
#  Để cà phê ra hoa đồng loạt, hãy đảm bảo rằng bạn tưới nước sau thời kỳ khô hạn khi nụ hoa đã hình thành hoàn toàn tại đốt cuối cùng trên mỗi nhánh. Tưới nước đúng cách trong đợt đầu tiên với lượng thích hợp phụ thuộc vào điều kiện môi trường cụ thể như kiểu khí hậu địa phương, chất lượng đất và sức khỏe tổng quát của cây trồng. Bằng cách tuân theo những hướng dẫn này, bạn có thể thúc đẩy sự nở rộ đều đặn và hiệu quả hơn từ vườn cà phê của bạn. </s>
#  Tôi không biết trả lời câu hỏi này. </s>
#  Để phòng trừ bệnh khô cành khô quả cho cây cà phê, cần áp dụng tổng hợp các biện pháp như trồng cây che bóng, cây ăn quả với mật độ hợp lý, bón phân đầy đủ, kiểm tra vườn cây thường xuyên và xử lý bằng thuốc hóa học khi cần thiết. </s>
#  Đối với cây hồ tiêu, lượng nước tưới khuyến nghị trong mô hình trồng hồ tiêu xen cà phê là từ 100-120 lít nước cho mỗi gốc/lần, hoặc có thể tưới tiết kiệm với khoảng 80-100 lít nước cho mỗi gốc/lần. Tưới 4 lần, mỗi chu kỳ tưới cách nhau 25-30 ngày. </s>
#  Sau khi thu hoạch sầu riêng, cần thực hiện vệ sinh gốc cây, tỉa cành và bón phân để chăm sóc cây. </s>
# Cannot find document revelance
# Cannot find document revelance
#  Tên khoa học của cây đủng đỉnh là Caryota mitis. </s>
#  Thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê là trước khi tiến hành bón phân và trước khi mùa mưa bắt đầu. </s>
#   42,66 triệu tấn </s>
# Cannot find document revelance
#  Các cành không mang trái, cành già yếu, cành bị nhiễm bệnh nên được loại bỏ vì chúng cản trở ánh nắng mặt trời tiếp cận phần còn lại của cây, dẫn đến tăng trưởng kém hiệu quả hơn. Chúng cũng góp phần gây mất cân bằng dinh dưỡng do tiêu thụ tài nguyên mà lẽ ra sẽ dành cho những bộ phận khỏe mạnh khác của cây. Hơn nữa, chúng có thể thu hút sâu bệnh hại, ảnh hưởng xấu đến sức khỏe tổng thể của cây trồng. Bằng cách loại bỏ những cành như vậy, người ta giúp duy trì môi trường lành mạnh và hỗ trợ cho toàn bộ khu vườn. </s>
#  Để chăm sóc đúng cách cây lan chi, hãy đảm bảo rằng nó nhận được ánh sáng 1 phần, đất mùn với độ pH từ 6 - 7.5, và đất thoát nước tốt. Tưới nước đều đặn, tránh sử dụng nước bị nhiễm phèn. Cây thích nghi tốt với điều kiện ấm áp hơn, khoảng 20°C (68°F). Cắt tỉa lá vàng hoặc hư hỏng để thúc đẩy sự phát triển khỏe mạnh. Nếu muốn nhân giống cây lan chi, bạn có thể tách bụi cây con sau mỗi năm rưỡi đến hai năm. </s>
#  Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á, là loài thực vật thuộc chi Sầu riêng phổ biến nhất. </s>
# Cannot find document revelance
#  Tôi không biết trả lời câu hỏi này. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Tôi không biết trả lời câu hỏi này. </s>
# ________________________________________________________________________________
# Top k: 5  ----- Threshold: 0.65
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Cây nha đam có nhiều lợi ích cho sức khỏe như sát khuẩn, chống lão hóa, giảm sưng, viêm, bảo vệ đường ruột, dạ dày, giúp cải thiện chất lượng giấc ngủ và hỗ trợ chức năng não bộ. </s>
#  Để chăm sóc đúng cách cây lan Vanda, hãy đảm bảo rằng nó nhận được nhiệt độ từ 25 - 30 độ C, duy trì độ ẩm khoảng 70-80%. Tưới nước đều đặn, đặc biệt là trong thời kỳ khô hạn hoặc mùa hè. Cây cũng thích ánh sáng mạnh, vì vậy đặt chúng dưới ánh mặt trời trực tiếp hoặc sử dụng bóng đèn chuyên dùng cho cây cảnh. Ngoài ra, bón phân cân đối mỗi tuần một lần trong suốt cả năm để thúc đẩy sự phát triển khỏe mạnh. </s>
#  Để phòng trừ côn trùng và nấm bệnh cho cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây. </s>
#  Để trồng và chăm sóc cây chu đinh lan, hãy làm theo những bước sau:
#
# 1. Chọn loại đất phù hợp: Sử dụng đất thịt, đất mùn hoặc đất cát pha với tính thấm nước cao và giữ ẩm tốt. Đảm bảo rằng đất tơi xốp và thoáng khí.
#
# 2. Nhân giống: Thực hiện phương pháp nhân giống bằng cách tách bụi. Chờ cho cây mẹ lớn lên rồi mới bắt đầu tách cây con.
#
# 3. Chuẩn bị chậu: Đặt chất trồng vào chậu sao cho nó bao phủ khoảng 1/3 củ. Vì rễ cây rất dễ bị thối nên tránh chôn sâu hơn nữa. Bạn không cần phải có nhiều củ như đối với các loài lan khác.
#
# 4. Tưới nước: Ngay sau khi trồng, tưới nước để duy trì độ ẩm cho cây. Chu đinh lan là loài có sức sống mạnh mẽ và ít yêu cầu chăm sóc, vì vậy việc tưới nước thường xuyên không cần thiết. Thông thường, tưới mỗi tuần hai lần là đủ.
#
# 5. Điều kiện ánh sáng: Đảm bảo cây nhận được ít nhất tám giờ ánh nắng trực tiếp mỗi ngày.
#
# 6. Độ ẩm: Duy trì mức độ ẩm từ 60% đến 70 %.
#
# 7. Nhiệt độ: Cây thích nghi tốt với cả điều kiện nóng và lạnh, miễn là chúng nằm trong phạm vi từ 10°C đến 35°C (50°F đến 95°F).
#
# Bằng cách tuân thủ những hướng dẫn này, bạn có thể giúp cây chu đinh lan của mình khỏe mạnh và ra nhiều hoa. </s>
#  Để chăm sóc hoa lan Cattleya, hãy chọn giá thể thoáng rễ, có khả năng thoát nước nhanh nhưng vẫn giữ ẩm tốt. Chọn những cây khỏe mạnh với tép to và màu xanh tốt. Tạo móc treo để hỗ trợ cây và đặt nó vào chậu, đảm bảo rằng chỉ có gốc tiếp xúc với giá thể. Tưới nước đều đặn và bón phân cân đối mỗi tháng một lần. Giữ môi trường ấm áp và sáng sủa, tránh ánh nắng trực tiếp và gió lùa. Cắt tỉa cành chết và thay chậu sau hai năm. </s>
#  Để điều trị sâu ăn lá hoặc bám vào cây hoa Lan Cattleya, hãy xem xét việc phun thuốc diệt sâu bệnh hoặc loại bỏ chúng khỏi cây. Ngoài ra, cũng nên cắt bỏ bất kỳ cành lá bị khô héo hoặc nhiễm bệnh. </s>
#   </s>
#  Để bổ sung chất hữu cơ cho đất sau thu hoạch đối với vườn cây ăn trái, hãy tuân theo những phương pháp sau đây :
# 1. Bổ sung dinh dưỡng và chất hữu cơ cho đất: Sử dụng phân chuồng ủ hoai mục, phân xanh, phân trùn quế, đạm cá, phân NPK hữu cơ,...
# 2. Che phủ bằng cách để cỏ hoặc dùng nguyên liệu hữu cơ: Cỏ hoặc các loại nguyên liệu khác như rơm rạ, cành lá khô, tàn dư hoa màu, bèo lục bình, thân lá chuối, trấu... sẽ rất tốt cho việc bổ sung thêm chất hữu cơ cho đất.
# 3. Bổ sung vi sinh vật vào đất để cải tạo đất sau thu hoạch: Sử dụng phân bón vi sinh để cân bằng hệ sinh thái vi sinh vật trong đất nhằm cải thiện sức khỏe tổng quát của đất. </s>
#  Thời điểm tốt nhất để bón đạm cho lúa là trước lúc cấy và lúc cây lúa bắt đầu làm đòng. Không nên bón đạm ngay sau khi cấy và tránh bón trong điều kiện thời tiết bất lợi như chuẩn bị mưa lớn hoặc nắng nóng gay gắt. Bón đạm hiệu quả hơn vào buổi sáng hoặc chiều tối. </s>
#  Để khắc phục nứt trái trên cây trồng, hãy đảm bảo rằng cây nhận đủ lượng nước cần thiết mà không phải đối mặt với sự dư thừa. Ngoài ra, kiểm soát sâu bệnh như vi khuẩn và nấm bằng cách sử dụng thuốc trừ sâu thích hợp. Cắt tỉa những cành mọc dày đặc để cải thiện lưu thông gió và giảm nguy cơ nhiễm trùng. Cuối cùng, áp dụng lớp phủ hữu cơ để giữ ẩm và ngăn chặn cỏ dại cạnh tranh chất dinh dưỡng. </s>
# Cannot find document revelance
#  Để cà phê ra hoa đồng loạt, hãy đảm bảo rằng bạn tưới nước sau thời kỳ khô hạn khi nụ hoa đã hình thành hoàn toàn tại đốt cuối cùng trên mỗi nhánh. Tưới nước đúng cách trong đợt đầu tiên với lượng thích hợp phụ thuộc vào điều kiện môi trường cụ thể như kiểu khí hậu địa phương, chất lượng đất và sức khỏe tổng quát của cây trồng. Bằng cách tuân theo những hướng dẫn này, bạn có thể thúc đẩy sự nở rộ đều đặn và hiệu quả hơn từ vườn cà phê của bạn. </s>
#  Tôi không biết trả lời câu hỏi này. </s>
#  Để phòng trừ bệnh khô cành khô quả cho cây cà phê, cần áp dụng tổng hợp các biện pháp như trồng cây che bóng, cây ăn quả với mật độ hợp lý, bón phân đầy đủ, kiểm tra vườn cây thường xuyên và xử lý bằng thuốc hóa học khi cần thiết. </s>
#  Đối với cây hồ tiêu, lượng nước tưới khuyến nghị trong mô hình trồng hồ tiêu xen cà phê là từ 100-120 lít nước cho mỗi gốc/lần, hoặc có thể tưới tiết kiệm với khoảng 80-100 lít nước cho mỗi gốc/lần. Tưới 4 lần, mỗi chu kỳ tưới cách nhau 25-30 ngày. </s>
#  Sau khi thu hoạch sầu riêng, cần thực hiện vệ sinh gốc cây, tỉa cành và bón phân để chăm sóc cây. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê là trước khi tiến hành bón phân và trước khi mùa mưa bắt đầu. </s>
#   42,66 triệu tấn </s>
# Cannot find document revelance
#  Các cành không mang trái, cành già yếu, cành bị nhiễm bệnh nên được loại bỏ vì chúng cản trở ánh nắng mặt trời tiếp cận phần còn lại của cây, dẫn đến tăng trưởng kém hiệu quả hơn. Chúng cũng góp phần gây mất cân bằng dinh dưỡng do tiêu thụ tài nguyên mà lẽ ra sẽ dành cho những bộ phận khỏe mạnh khác của cây. Hơn nữa, chúng có thể thu hút sâu bệnh hại, ảnh hưởng xấu đến sức khỏe tổng thể của cây trồng. Bằng cách loại bỏ những cành như vậy, người ta giúp duy trì môi trường lành mạnh và hỗ trợ cho toàn bộ khu vườn. </s>
#  Để chăm sóc đúng cách cây lan chi, hãy đảm bảo rằng nó nhận được ánh sáng 1 phần, đất mùn với độ pH từ 6 - 7.5, và đất thoát nước tốt. Tưới nước đều đặn, tránh sử dụng nước bị nhiễm phèn. Cây thích nghi tốt với điều kiện ấm áp hơn, khoảng 20°C (68°F). Cắt tỉa lá vàng hoặc hư hỏng để thúc đẩy sự phát triển khỏe mạnh. Nếu muốn nhân giống cây lan chi, bạn có thể tách bụi cây con sau mỗi năm rưỡi đến hai năm. </s>
#  Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á, là loài thực vật thuộc chi Sầu riêng phổ biến nhất. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Tôi không biết trả lời câu hỏi này. </s>
# ________________________________________________________________________________
# Top k: 5  ----- Threshold: 0.7
# Cannot find document revelance
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
#  Để chăm sóc đúng cách cây lan Vanda, hãy tuân theo các bước sau đây :
# 1. Đảm bảo nhiệt độ từ 25 - 30C bằng cách che mát hoặc thắp đèn sưởi ấm tùy thuộc vào môi trường.
# 2. Duy trì độ ẩm 70-80% để ngăn chặn sự héo úa của lá và suy giảm sức khỏe tổng thể.
# 3. Tưới nước thường xuyên, đặc biệt là trong thời kỳ khô hạn, ví dụ như mùa hè. Nhà kính đòi hỏi lượng nước lớn hơn so với ngoài trời do tốc độ bay hơi cao hơn. Có thể tưới mỗi ngày hai đến ba lần đối với nhà kính và năm lần đối với bên ngoài.
# 4. Lan Vanda thích ánh sáng mạnh và sẽ nở hoa dưới cường độ chiếu sáng cao. Đặt chúng gần cửa sổ hướng Nam hoặc sử dụng hệ thống chiếu sáng nhân tạo chuyên dùng cho cây cối.
# 5. Bón phân cân đối hàng tuần trong suốt cả năm vì loài lan này có nhu cầu dinh dưỡng cao. Sử dụng loại phân bón tan chậm giải phóng chất dinh dưỡng đều đặn.
# 6. Thay chậu vài năm một lần để cung cấp đất mới và kích thước chậu phù hợp với rễ đang phát triển. Chọn hỗn hợp bầu gồm vỏ cây, rêu than bùn và đá trân châu để thoát nước tốt.
# 7. Kiểm tra sâu bệnh định kỳ và xử lý kịp thời để tránh lây nhiễm sang các cây khác.
# Bằng cách chú ý đến các yêu cầu cụ thể này, bạn có thể nuôi dưỡng thành công cây lan Vanda rực rỡ và thơm ngát. </s>
#  Để phòng trừ côn trùng và nấm bệnh cho cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây. </s>
#  Để trồng và chăm sóc cây chu đinh lan, hãy làm theo những bước sau:
#
# 1. Chọn loại đất phù hợp: Sử dụng đất thịt, đất mùn hoặc đất cát pha với tính thấm nước cao và giữ ẩm tốt. Đảm bảo rằng đất tơi xốp và thoáng khí.
#
# 2. Nhân giống: Thực hiện phương pháp nhân giống bằng cách tách bụi. Chờ cho cây mẹ lớn lên rồi mới bắt đầu tách cây con.
#
# 3. Chuẩn bị chậu: Đặt chất trồng vào chậu sao cho nó bao phủ khoảng 1/3 củ. Vì rễ cây rất dễ bị thối nên tránh chôn sâu hơn nữa. Bạn không cần phải có nhiều củ như đối với các loài lan khác.
#
# 4. Tưới nước: Ngay sau khi trồng, tưới nước để duy trì độ ẩm cho cây. Chu đinh lan là loài có sức sống mạnh mẽ và ít yêu cầu chăm sóc, vì vậy việc tưới nước thường xuyên không cần thiết. Thông thường, tưới mỗi tuần hai lần là đủ.
#
# 5. Điều kiện ánh sáng: Đảm bảo cây nhận được ít nhất tám giờ ánh nắng trực tiếp mỗi ngày.
#
# 6. Độ ẩm: Duy trì mức độ ẩm từ 60% đến 70 %.
#
# 7. Nhiệt độ: Cây thích nghi tốt với cả điều kiện nóng và lạnh, miễn là chúng nằm trong phạm vi từ 10°C đến 35°C (50°F đến 95°F).
#
# Bằng cách tuân thủ những hướng dẫn này, bạn có thể giúp cây chu đinh lan của mình khỏe mạnh và ra nhiều hoa. </s>
#  Để chăm sóc hoa lan Cattleya, hãy tuân theo các bước sau đây:
# 1. Lựa chọn giá thể phù hợp với tính chất thoáng rễ, thoát nước nhanh nhưng vẫn giữ ẩm tốt.
# 2. Chọn giống lan Cattleya khỏe mạnh, tép to, màu xanh tốt và không có dấu hiệu bị bệnh hoặc lá màu khác thường.
# 3. Tạo móc treo để tạo điểm tựa cho cây.
# 4. Đặt giá thể vào chậu, bắt đầu bằng kích thước lớn nhất và giảm dần, để cách miệng chậu khoảng 2-3cm.
# 5. Đặt nhánh lan ở phía bên cạnh chậu sao cho phần mắt ngủ hướng vào giữa chậu. Cố định giả hành vào móc treo bằng dây để tăng thêm độ vững chắc.
# 6. Đảm bảo rằng thân cây chỉ tiếp xúc với bề mặt giá thể.
# 7. Tưới nước đều đặn cho cây, tránh tưới quá nhiều vì nó có thể dẫn đến thối rữa.
# 8. Bón phân cân đối mỗi tháng một lần trong mùa sinh trưởng (tháng 3 - tháng 9) và bón ít hơn trong thời kỳ nghỉ đông (tháng 10 - tháng 2).
# 9. Theo dõi cây để phát hiện sớm các dấu hiệu nhiễm nấm hoặc vi khuẩn và xử lý kịp thời.
# 10. Cắt tỉa bỏ lá chết hoặc hư hỏng để duy trì vẻ ngoài thẩm mỹ và ngăn ngừa lây lan mầm bệnh.
# Bằng việc tuân thủ các bước này, bạn có thể chăm sóc đúng đắn cho hoa lan Cattleya và tận hưởng vẻ đẹp cũng như lợi ích tinh thần của chúng. </s>
#  Để điều trị sâu ăn lá hoặc bám vào cây hoa Lan Cattleya, hãy xem xét việc phun thuốc diệt sâu bệnh hoặc loại bỏ chúng khỏi cây. Ngoài ra, cũng nên cắt bỏ bất kỳ cành lá bị khô héo hoặc nhiễm bệnh. </s>
#   </s>
#  Để bổ sung chất hữu cơ cho đất sau thu hoạch đối với vườn cây ăn trái, hãy tuân theo những phương pháp sau đây :
# 1. Bổ sung dinh dưỡng và chất hữu cơ cho đất: Sử dụng phân chuồng ủ hoai mục, phân xanh, phân trùn quế, đạm cá, phân NPK hữu cơ,...
# 2. Che phủ bằng cách để cỏ hoặc dùng nguyên liệu hữu cơ: Cỏ hoặc các loại nguyên liệu khác như rơm rạ, cành lá khô, tàn dư hoa màu, bèo lục bình, thân lá chuối, trấu... sẽ rất tốt cho việc bổ sung thêm chất hữu cơ cho đất.
# 3. Bổ sung vi sinh vật vào đất để cải tạo đất sau thu hoạch: Sử dụng phân bón vi sinh để cân bằng hệ sinh thái vi sinh vật trong đất nhằm cải thiện sức khỏe tổng quát của đất. </s>
#  Thời điểm tốt nhất để bón đạm cho lúa là trước lúc cấy và lúc cây lúa bắt đầu làm đòng. Không nên bón đạm ngay sau khi cấy và tránh bón trong điều kiện thời tiết bất lợi như chuẩn bị mưa lớn hoặc nắng nóng gay gắt. Bón đạm hiệu quả hơn vào buổi sáng hoặc chiều tối. </s>
#  Tôi không biết trả lời câu hỏi này. </s>
# Cannot find document revelance
#  Để cà phê ra hoa đồng loạt, hãy đảm bảo rằng bạn tưới nước sau thời kỳ khô hạn khi nụ hoa đã hình thành hoàn toàn tại đốt cuối cùng trên mỗi nhánh. Tưới nước đúng cách trong đợt đầu tiên với lượng thích hợp phụ thuộc vào điều kiện môi trường cụ thể như kiểu khí hậu địa phương, chất lượng đất và sức khỏe tổng quát của cây trồng. Bằng cách tuân theo những hướng dẫn này, bạn có thể thúc đẩy sự nở rộ đều đặn và hiệu quả hơn từ vườn cà phê của bạn. </s>
#  Tôi không biết trả lời câu hỏi này. </s>
#  Để phòng trừ bệnh khô cành khô quả cho cây cà phê, cần áp dụng tổng hợp các biện pháp như trồng cây che bóng, cây ăn quả với mật độ hợp lý, bón phân đầy đủ, kiểm tra vườn cây thường xuyên và xử lý bằng thuốc hóa học khi cần thiết. </s>
#  Đối với cây hồ tiêu, lượng nước tưới khuyến nghị trong mô hình trồng hồ tiêu xen cà phê là từ 100-120 lít nước cho mỗi gốc/lần, hoặc có thể tưới tiết kiệm với khoảng 80-100 lít nước cho mỗi gốc/lần. Tưới 4 lần, mỗi chu kỳ tưới cách nhau 25-30 ngày. </s>
#  Vệ sinh gốc sầu riêng bằng cách quét dọn, thu gom lá cây và làm sạch cỏ xung quanh gốc cây; tỉa cành để tạo điều kiện thông thoáng và giảm nguy cơ bị tấn công bởi sâu bệnh; bón phân cân đối NPK với tỷ lệ 1-2-3 hoặc 1-1,5-2,5 để giúp cây nhanh chóng phục hồi năng lượng dự trữ trong giai đoạn mang hoa, đậu quả trước đó. Ngoài ra, sử dụng thuốc diệt nấm như Benomyl, Ridomil Gold, Aliette phun lên thân, rễ cây để phòng ngừa nhiễm khuẩn từ đất gây chết cây. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Thời điểm tốt nhất để thực hiện kỹ thuật cắt tỉa và tạo tán cho cây cà phê là trước khi tiến hành bón phân và trước khi mùa mưa bắt đầu. </s>
#   42,66 triệu tấn </s>
# Cannot find document revelance
# Cannot find document revelance
#  Để chăm sóc đúng cách cây lan chi, hãy đảm bảo rằng nó nhận được ánh sáng 1 phần, đất mùn với độ pH từ 6 - 7.5, và đất thoát nước tốt. Tưới nước đều đặn, tránh sử dụng nước bị nhiễm phèn. Cây thích nghi tốt với điều kiện ấm áp hơn, khoảng 20°C (68°F). Cắt tỉa lá vàng hoặc hư hỏng để thúc đẩy sự phát triển khỏe mạnh. Nếu muốn nhân giống cây lan chi, bạn có thể tách bụi cây con sau mỗi năm rưỡi đến hai năm. </s>
#  Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á, là loài thực vật thuộc chi Sầu riêng phổ biến nhất. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# ________________________________________________________________________________
# Top k: 5  ----- Threshold: 0.75
# Cannot find document revelance
# Cannot find document revelance
#  Để
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# phòng trừ côn trùng và nấm bệnh cho cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây. </s>
#  Để trồng và chăm sóc cây lan chu đinh, hãy làm theo các bước sau đây:
# 1. Chọn loại đất phù hợp (đất thịt, đất mùn hoặc đất cát) với độ tơi xốp, khả năng thoát nước và giữ ẩm cao.
# 2. Trồng cây ở nơi có ánh sáng mặt trời đầy đủ nhưng tránh nắng trực tiếp.
# 3. Tưới nước thường xuyên để duy trì độ ẩm cho đất.
# 4. Bón phân cân đối mỗi tháng một lần trong mùa sinh trưởng.
# 5. Cắt tỉa những cành chết hoặc hư hỏng để thúc đẩy sự phát triển mới.
# 6. Nhân giống bằng phương pháp tách bụi, chọn bụi đã lớn và khỏe mạnh rồi dùng dao sắc cắt rời phần thân bên ngoài.
# 7. Gieo hạt xuống đất sâu khoảng 0,5 cm và tưới nhẹ nhàng.
# 8. Che phủ khu vực gieo hạt bằng vật liệu bảo vệ khỏi mưa quá nhiều.
# 9. Khi cây con mọc lên thì di dời chúng sang vị trí mong muốn.
# Bằng cách tuân thủ những hướng dẫn này, bạn sẽ đảm bảo rằng cây lan chu đinh của bạn phát triển mạnh mẽ và mang lại vẻ đẹp cũng như lợi ích sức khỏe mà nó cung cấp. </s>
#  Để chăm sóc hoa lan Cattleya, hãy đảm bảo rằng nó nhận đủ ánh sáng mặt trời trực tiếp hoặc gián tiếp, duy trì độ ẩm phù hợp bằng cách phun sương thường xuyên, tưới nước đều đặn nhưng tránh ngập lụt, cung cấp chất dinh dưỡng cân đối trong suốt mùa sinh trưởng và thay chậu mỗi năm với hỗn hợp giá thể mới bao gồm xơ dừa, than củi, đá bọt, hoặc các vật liệu thoát nước khác. </s>
# Cannot find document revelance
# Cannot find document revelance
#  Để bổ sung chất hữu cơ cho đất sau thu hoạch đối với vườn cây ăn trái, hãy tuân theo những phương pháp sau đây :
# 1. Bổ sung dinh dưỡng và chất hữu cơ cho đất: Sử dụng phân chuồng ủ hoai mục, phân xanh, phân trùn quế, đạm cá, phân NPK hữu cơ,...
# 2. Che phủ bằng cách để cỏ hoặc dùng nguyên liệu hữu cơ: Cỏ hoặc các loại nguyên liệu khác như rơm rạ, cành lá khô, tàn dư hoa màu, bèo lục bình, thân lá chuối, trấu... sẽ rất tốt cho việc bổ sung thêm chất hữu cơ cho đất.
# 3. Bổ sung vi sinh vật vào đất để cải tạo đất sau thu hoạch: Sử dụng phân bón vi sinh để cân bằng hệ sinh thái vi sinh vật trong đất nhằm cải thiện sức khỏe tổng quát của đất. </s>
#  Thời điểm tốt nhất để bón đạm cho lúa là trước lúc cấy và lúc cây lúa bắt đầu làm đòng. Không nên bón đạm ngay sau khi cấy và tránh bón trong điều kiện thời tiết bất lợi như chuẩn bị mưa lớn hoặc nắng nóng gay gắt. Bón đạm hiệu quả hơn vào buổi sáng hoặc chiều tối. </s>
# Cannot find document revelance
# Cannot find document revelance
#  Để cà phê ra hoa đồng loạt, hãy đảm bảo rằng bạn tưới nước sau thời kỳ khô hạn khi nụ hoa đã hình thành hoàn toàn tại đốt cuối cùng trên mỗi nhánh. Tưới nước đúng cách trong đợt đầu tiên với lượng thích hợp phụ thuộc vào điều kiện môi trường cụ thể như kiểu khí hậu địa phương, chất lượng đất và sức khỏe tổng quát của cây trồng. Bằng cách tuân theo những hướng dẫn này, bạn có thể thúc đẩy sự nở rộ đều đặn và hiệu quả hơn từ vườn cà phê của bạn. </s>
# Cannot find document revelance
#  Để phòng trừ bệnh khô cành khô quả cho cây cà phê, cần áp dụng tổng hợp các biện pháp như trồng cây che bóng, cây ăn quả với mật độ hợp lý, bón phân đầy đủ, kiểm tra vườn cây thường xuyên và xử lý bằng thuốc hóa học khi cần thiết. </s>
# Cannot find document revelance
#  Vệ sinh gốc sầu riêng bằng cách quét dọn, thu gom lá cây và làm sạch cỏ xung quanh gốc cây; tỉa cành để tạo điều kiện thông thoáng và giảm nguy cơ bị tấn công bởi sâu bệnh; bón phân cân đối NPK với tỷ lệ 1-2-3 hoặc 1-1,5-2,5 để giúp cây nhanh chóng phục hồi năng lượng dự trữ trong giai đoạn mang hoa, đậu quả trước đó. Ngoài ra, sử dụng thuốc diệt nấm như Benomyl, Ridomil Gold, Aliette phun lên thân, rễ cây để phòng ngừa nhiễm khuẩn từ đất gây chết cây. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Tôi không biết trả lời câu hỏi này. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Để chăm sóc đúng cây lan chi, hãy đảm bảo rằng nó được trồng trên đất tơi xốp, thoát nước tốt với độ pH từ hơi chua đến trung tính (pH 5-7). Tưới nước thường xuyên nhưng tránh tưới quá nhiều vì điều đó có thể gây thối rễ. Cung cấp ánh sáng gián tiếp hoặc lọc nắng trực tiếp, đặc biệt là trong mùa hè. Bón phân cân đối mỗi tháng một lần trong suốt mùa sinh trưởng. Cắt tỉa những bông hoa đã chết sau khi chúng tàn để khuyến khích việc ra hoa mới. </s>
#  Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á, là loài thực vật thuộc chi Sầu riêng phổ biến nhất. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# ________________________________________________________________________________
# Top k: 5  ----- Threshold: 0.8
# Cannot find document revelance
# Cannot find document revelance
#  Để
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:362: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /home/trung/miniconda3/envs/dev/lib/python3.8/site-packages/transformers/generation/configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# phòng trừ côn trùng và nấm bệnh cho cây sầu riêng, sử dụng các sản phẩm sinh học và chất phòng trừ côn trùng/nấm bệnh định kỳ. Việc chăm sóc sầu riêng trong giai đoạn nuôi trái rất quan trọng đối với sức khỏe tổng thể và sự phát triển của cây. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Vệ sinh gốc sầu riêng bằng cách quét dọn, thu gom lá cây và làm sạch cỏ xung quanh gốc cây; tỉa cành để tạo điều kiện thông thoáng và giảm nguy cơ bị tấn công bởi sâu bệnh; bón phân cân đối NPK với tỷ lệ 1-2-3 hoặc 1-1,5-2,5 để giúp cây nhanh chóng phục hồi năng lượng dự trữ trong giai đoạn mang hoa, đậu quả trước đó. Ngoài ra, sử dụng thuốc diệt nấm như Benomyl, Ridomil Gold, Aliette phun lên thân, rễ cây để phòng ngừa nhiễm khuẩn từ đất gây chết cây. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
#  Durio zibethinus, còn được gọi là Sầu riêng Đông Nam Á, là loài thực vật thuộc chi Sầu riêng phổ biến nhất. </s>
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# Cannot find document revelance
# ________________________________________________________________________________

# %%
print("__" * 100)
# Out:
# ________________________________________________________________________________________________________________________________________________________________________________________________________
